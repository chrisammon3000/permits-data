# %% [markdown]
# # permits-data / Clean Data
#
# ETL pipeline for construction permits data in Los Angeles, California, USA.
#
# For more information:
# https://data.lacity.org/A-Prosperous-City/Building-and-Safety-Permit-Information/yv23-pmwf

# %% [markdown]
# ## Setup

# %%
import os
import sys

# Set path for modules
sys.path[0] = '../'

from dotenv import load_dotenv, find_dotenv
import numpy as np
import pandas as pd
import psycopg2

# Import custom eda and sql functions
from src.toolkits.eda import get_snapshot, explore_value_counts
from src.toolkits.sql import connect_db

# Import dependencies for geocoding
from geopy.geocoders import Nominatim
from geopy.geocoders import GoogleV3
from geopy.extra.rate_limiter import RateLimiter

# %%
# Set notebook display options
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
# Get project root directory
root_dir = os.path.dirname(os.getcwd())

# Set environment variables
load_dotenv(find_dotenv());
POSTGRES_USER = os.getenv("POSTGRES_USER")
POSTGRES_PASSWORD = os.getenv("POSTGRES_PASSWORD")
POSTGRES_DB = os.getenv("POSTGRES_DB")
DB_PORT = os.getenv("DB_PORT")
DB_HOST = os.getenv("DB_HOST")
DATA_URL = os.getenv("DATA_URL")

# Google Maps environment variables
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# Environment variables specific to notebook
DATA_DIR = os.path.dirname(root_dir) + '/data'
DB_TABLE = "permits_raw"

# %% [markdown]
# ## 1. Clean Data

# %%
# Connect to db
conn = connect_db()

# Extract partial dataset
sql_all = 'SELECT * FROM {} LIMIT 1500;'.format(DB_TABLE)

# Columns to parse as dates
date_columns = ['status_date', 'issue_date', 'license_expiration_date']

# Fetch fresh data
data = pd.read_sql_query(sql_all, conn, parse_dates=date_columns, coerce_float=False)

# Replace None with np.nan
data.fillna(np.nan, inplace=True)
# Out:
# Connected as user "postgres" to database "permits" on localhost:5432

# %% [markdown]
# ### 1.1 Missing Data

# %% [markdown]
# #### Overview of Unique Values in Qualitative Data
#
# Before making decisions about how to address missing values, it is important to be familiar with the content of each column. In some cases data can be left alone, imputed, recollected, or dropped from the dataset. Since the permits data has mostly qualitative data and unstructured text, most of it will be left alone.
#
# In the case of geographic data such as addresses and lat/long coordinates, it will be necessary to accurately geocode the missing values. Since this information is split across several columns they will be concatenated into one column.

# %%
# Get an overview of data types, # unique values, # missing values and sample value
# for each column
get_snapshot(data)
# Out:
#                                              DATA TYPE  # UNIQUE VALUES  \
# COLUMN
# assessor_book                                  float64              742
# assessor_page                                  float64               49
# assessor_parcel                                 object              111
# tract                                           object             1202
# block                                           object               96
# lot                                             object              296
# reference_no_old_permit_no                      object              520
# pcis_permit_no                                  object             1500
# status                                          object               11
# status_date                             datetime64[ns]              962
# permit_type                                     object               15
# permit_sub_type                                 object                6
# permit_category                                 object                2
# project_number                                 float64                3
# initiating_office                               object                6
# issue_date                              datetime64[ns]              976
# address_start                                    int64             1327
# address_fraction_start                          object                3
# address_end                                      int64             1325
# address_fraction_end                            object                4
# street_direction                                object                4
# street_name                                     object              957
# street_suffix                                   object               16
# suffix_direction                                object                5
# unit_range_start                                object              249
# unit_range_end                                  object               28
# zip_code                                       float64              114
# work_description                                object              570
# valuation                                       object              177
# floor_area_la_zoning_code_definition            object               69
# no_of_residential_dwelling_units               float64               14
# no_of_stories                                  float64                7
# contractors_business_name                       object             1044
# contractor_address                              object             1057
# contractor_city                                 object              231
# contractor_state                                object               17
# license_type                                    object               24
# license_no                                       int64             1017
# principal_first_name                            object              509
# principal_middle_name                           object              396
# principal_last_name                             object              903
# license_expiration_date                 datetime64[ns]              107
# applicant_first_name                            object              604
# applicant_last_name                             object              735
# applicant_business_name                         object              116
# applicant_address_1                             object              674
# applicant_address_2                             object              157
# applicant_address_3                             object              249
# zone                                            object              310
# occupancy                                       object                2
# floor_area_la_building_code_definition          object               91
# census_tract                                    object              694
# council_district                                 int64               15
# latitude_longitude                              object             1399
# applicant_relationship                          object               12
# existing_code                                  float64               20
# proposed_code                                  float64               16
#
#                                         # MISSING VALUES  \
# COLUMN
# assessor_book                                          1
# assessor_page                                          1
# assessor_parcel                                        1
# tract                                                  5
# block                                               1178
# lot                                                   14
# reference_no_old_permit_no                           877
# pcis_permit_no                                         0
# status                                                 0
# status_date                                            0
# permit_type                                            0
# permit_sub_type                                        0
# permit_category                                        0
# project_number                                      1485
# initiating_office                                      0
# issue_date                                             0
# address_start                                          0
# address_fraction_start                              1476
# address_end                                            0
# address_fraction_end                                1457
# street_direction                                      18
# street_name                                            0
# street_suffix                                         38
# suffix_direction                                    1491
# unit_range_start                                    1203
# unit_range_end                                      1470
# zip_code                                               1
# work_description                                     877
# valuation                                            984
# floor_area_la_zoning_code_definition                1397
# no_of_residential_dwelling_units                    1449
# no_of_stories                                       1402
# contractors_business_name                              0
# contractor_address                                   168
# contractor_city                                      179
# contractor_state                                     179
# license_type                                           0
# license_no                                             0
# principal_first_name                                 157
# principal_middle_name                                558
# principal_last_name                                  166
# license_expiration_date                              106
# applicant_first_name                                 323
# applicant_last_name                                  476
# applicant_business_name                             1338
# applicant_address_1                                  670
# applicant_address_2                                 1247
# applicant_address_3                                  676
# zone                                                   2
# occupancy                                           1480
# floor_area_la_building_code_definition               294
# census_tract                                           1
# council_district                                       0
# latitude_longitude                                    58
# applicant_relationship                                41
# existing_code                                       1098
# proposed_code                                       1343
#
#                                                                              SAMPLE VALUE
# COLUMN
# assessor_book                                                                        2106
# assessor_page                                                                          17
# assessor_parcel                                                                       031
# tract                                                        CABRILLO BEACH HEIGHTS TRACT
# block                                                                                   9
# lot                                                                                    13
# reference_no_old_permit_no                                                      15WL68346
# pcis_permit_no                                                          15026-10000-00305
# status                                                                     Permit Finaled
# status_date                                                           2013-04-16 00:00:00
# permit_type                                                                    Electrical
# permit_sub_type                                                                Commercial
# permit_category                                                             No Plan Check
# project_number                                                                          5
# initiating_office                                                                   METRO
# issue_date                                                            2013-02-14 00:00:00
# address_start                                                                       19120
# address_fraction_start                                                                1/2
# address_end                                                                         13955
# address_fraction_end                                                                  1/2
# street_direction                                                                        S
# street_name                                                                        WALNUT
# street_suffix                                                                        BLVD
# suffix_direction                                                                     WEST
# unit_range_start                                                                     1704
# unit_range_end                                                                 BUILDING C
# zip_code                                                                            91436
# work_description                        SUPPLEMENTAL PERMIT TO ADD PROVIDED PARKING FO...
# valuation                                                                        25000.00
# floor_area_la_zoning_code_definition                                                  484
# no_of_residential_dwelling_units                                                       -1
# no_of_stories                                                                           1
# contractors_business_name                                         HERZOG M B ELECTRIC INC
# contractor_address                                             10680 W PICO BLVD STE #300
# contractor_city                                                                    ENCINO
# contractor_state                                                                       CA
# license_type                                                                          C36
# license_no                                                                         451059
# principal_first_name                                                                MARIO
# principal_middle_name                                                           MARCELINO
# principal_last_name                                                             WELTFREID
# license_expiration_date                                               2016-06-30 00:00:00
# applicant_first_name                                                                    L
# applicant_last_name                                                                 MOFFA
# applicant_business_name                                               JABS POOLS AND SPAS
# applicant_address_1                                                    4320 S RAYMOND AVE
# applicant_address_2                                                                   691
# applicant_address_3                                                           ANAHEIM, CA
# zone                                                                             RE15-1-H
# occupancy                                                                Misc. Occ. Group
# floor_area_la_building_code_definition                                                  0
# census_tract                                                                      1255.02
# council_district                                                                        3
# latitude_longitude                                                  (34.04893, -118.2572)
# applicant_relationship                                                      Net Applicant
# existing_code                                                                           5
# proposed_code                                                                          60

# %% [markdown]
# At the moment the only missing data of interest are *zip_code* and *latitude_longitude* coordinates, since these are necesary for mapping.

# %% [markdown]
# ### 1.2 Processing Missing Data
#
# ***Overview:***
# * 1.2.1 - Combine address columns into one columns: *full_address*<br>
#     - Correct *suffix_direction*
#     - Convert *zip_code* to string
#     - Concatenate to form *full_address*
# * 1.2.2 - Geocode missing *latitude_longitude* with *full_address*<br>
# * 1.2.3 - Split *latitude_longitude* into separate columns and convert to float values: *latitude*, *longitude*<br>
# <br>
# * Geocode missing *zip_code* with complete *latitude_longitude*<br>
# * Geocode any missing *full_address* with *latitude_longitude*<br>

# %% [markdown]
# #### 1.2.1 Concatenate *full_address*
#
# 1) Correct values *suffix_direction*.<br>
# 2) Convert *zip_code* to string.<br>
# 3) Concatenate to form a complete street address string.

# %%
# Truncate suffix_direction to first letter (N, S, E, W)
data['suffix_direction'] = data['suffix_direction'].str[0].fillna('')

# %%
# Convert zip_code to string
data['zip_code'] = data['zip_code'].astype(str).str[:-2]

# %%
# Combine address columns to concatenate
address_columns = ["address_start", "street_direction", "street_name", "street_suffix", "suffix_direction",
                  "zip_code"]
# Concatenate address values
data['full_address'] = data[address_columns].fillna('').astype(str).apply(' '.join, axis=1).str.replace('  ', ' ')

# %%
# Display
data[address_columns + ['full_address']].head()
# Out:
#    address_start street_direction street_name street_suffix suffix_direction  \
# 0           1823                S      THAYER           AVE
# 1           2122                W        54TH            ST
# 2            415                S  BURLINGTON           AVE
# 3            315                S      OCEANO            DR
# 4          13640                W      PIERCE            ST
#
#   zip_code                full_address
# 0    90025     1823 S THAYER AVE 90025
# 1    90062        2122 W 54TH ST 90062
# 2    90057  415 S BURLINGTON AVE 90057
# 3    90049       315 S OCEANO DR 90049
# 4    91331     13640 W PIERCE ST 91331

# %% [markdown]
# #### 1.2.2 Geocode missing *latitude_longitude*

# %%
# Extract rows missing latitude_longitude
data_missing = data[data['latitude_longitude'].isnull()==1]

# Size
data_missing.shape
# Out:
# (58, 60)

# %%
# Create helper function to geocode missing Latitude_Longitude values
def geocode(address):
    
    """Uses GoogleMaps API to geocode address strings to lat/long coordinates. RateLimiter is to 
    avoid timeout errors. Not all addresses can be geocoded, some NaN's will remain. Use of GoogleMaps 
    API incurs a charge at $0.005 per request."""
    
    if address:
        # Initializes GoogleMaps geocoder
        geolocator = GoogleV3(api_key=GOOGLE_API_KEY, 
                              user_agent="permits-data", 
                              timeout=None)

        # Adds Rate Limiter to space out requests
        geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

        # Geocode address input and format for dataframe
        location = geolocator.geocode(address)
        
        latitude, longitude = format(round(location.latitude, 7), '6f'), format(round(location.longitude, 7), '6f')
        
        return latitude, longitude
    else:
        return np.nan

# %%
# Calculate cost
cost = len(data_missing) * 0.005
print("Cost for geocoding {} addresses is ${:.2f}.".format(len(data_missing), cost))

# Geocode missing coordinates using full addresses
data_missing['latitude_longitude'] = data_missing['full_address'].apply(geocode)

# Update dataframe
data.update(data_missing)
# Out:
# Cost for geocoding 58 addresses is $0.29.
# /Users/gregory/anaconda3/envs/permits-data-env/lib/python3.5/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Check that there are no more missing coordinates before proceeding
assert data['latitude_longitude'].isnull().sum() == 0, "Missing coordinates must be geocoded."

# %% [markdown]
# #### 1.2.3 Split *latitude_longitude*
#
# Split coordinates into separate columns and convert to float values.

# %%
# Split latitude_longitude into separate columns and convert to float values: latitude, longitude
lat_long_series = data['latitude_longitude'].str[1:-1].str.split(',', expand=True) \
                        .astype(float).rename(columns={0: "latitude", 1: "longitude"})

# Add to original data
data = pd.concat([data, lat_long_series], axis=1)

# %%
# Display
data[['latitude_longitude', 'latitude', 'longitude']].head(1)
# Out:
#        latitude_longitude  latitude  longitude
# 0  (34.05474, -118.42628)  34.05474 -118.42628
