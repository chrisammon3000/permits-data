# %% [markdown]
# # permits-data / Clean Data
#
# ETL pipeline for construction permits data in Los Angeles, California, USA.
#
# For more information:
# https://data.lacity.org/A-Prosperous-City/Building-and-Safety-Permit-Information/yv23-pmwf

# %% [markdown]
# ## Setup

# %%
import os
import sys

# Set path for modules
sys.path[0] = '../'

from dotenv import load_dotenv, find_dotenv
import numpy as np
import pandas as pd
import psycopg2

# Import custom eda and sql functions
from src.toolkits.eda import get_snapshot, explore_value_counts
from src.toolkits.sql import connect_db

# Import dependencies for geocoding
from geopy.geocoders import Nominatim
from geopy.geocoders import GoogleV3
from geopy.extra.rate_limiter import RateLimiter

# %%
# Set notebook display options
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
# Get project root directory
root_dir = os.path.dirname(os.getcwd())

# Set environment variables
load_dotenv(find_dotenv());
POSTGRES_USER = os.getenv("POSTGRES_USER")
POSTGRES_PASSWORD = os.getenv("POSTGRES_PASSWORD")
POSTGRES_DB = os.getenv("POSTGRES_DB")
DB_PORT = os.getenv("DB_PORT")
DB_HOST = os.getenv("DB_HOST")
DATA_URL = os.getenv("DATA_URL")

# Google Maps environment variables
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# Environment variables specific to notebook
DATA_DIR = os.path.dirname(root_dir) + '/data'
DB_TABLE = "permits_raw"

# %% [markdown]
# ## 1. Clean Data

# %%
# Connect to db
conn = connect_db()

# Extract partial dataset
sql_all = 'SELECT * FROM {} LIMIT 500;'.format(DB_TABLE)

# Columns to parse as dates
date_columns = ['status_date', 'issue_date', 'license_expiration_date']

# Fetch fresh data
data = pd.read_sql_query(sql_all, conn, parse_dates=date_columns, coerce_float=False)

# Replace None with np.nan
data.fillna(np.nan, inplace=True)
# Out:
# Connected as user "postgres" to database "permits" on localhost:5432

# %%
#data.iloc[542]

# %% [markdown]
# ### 1.1 Missing Data

# %% [markdown]
# #### Overview of Unique Values in Qualitative Data
#
# Before making decisions about how to address missing values, it is important to be familiar with the content of each column. In some cases data can be left alone, imputed, recollected, or dropped from the dataset. Since the permits data has mostly qualitative data and unstructured text, most of it will be left alone.
#
# In the case of geographic data such as addresses and lat/long coordinates, it will be necessary to accurately geocode the missing values. Since this information is split across several columns they will be concatenated into one column.

# %%
# Get an overview of data types, # unique values, # missing values and sample value
# for each column
get_snapshot(data)
# Out:
#                                              DATA TYPE  # UNIQUE VALUES  \
# COLUMN
# assessor_book                                    int64              366
# assessor_page                                    int64               44
# assessor_parcel                                 object               74
# tract                                           object              446
# block                                           object               52
# lot                                             object              157
# reference_no_old_permit_no                      object              165
# pcis_permit_no                                  object              500
# status                                          object                8
# status_date                             datetime64[ns]              424
# permit_type                                     object               15
# permit_sub_type                                 object                5
# permit_category                                 object                2
# project_number                                 float64                2
# initiating_office                               object                6
# issue_date                              datetime64[ns]              436
# address_start                                    int64              476
# address_fraction_start                          object                2
# address_end                                      int64              476
# address_fraction_end                            object                2
# street_direction                                object                4
# street_name                                     object              395
# street_suffix                                   object               14
# suffix_direction                                object                2
# unit_range_start                                object               96
# unit_range_end                                  object               10
# zip_code                                         int64              105
# work_description                                object              186
# valuation                                       object               90
# floor_area_la_zoning_code_definition            object               20
# no_of_residential_dwelling_units               float64                5
# no_of_stories                                  float64                4
# contractors_business_name                       object              376
# contractor_address                              object              377
# contractor_city                                 object              149
# contractor_state                                object               13
# license_type                                    object               16
# license_no                                       int64              367
# principal_first_name                            object              229
# principal_middle_name                           object              182
# principal_last_name                             object              350
# license_expiration_date                 datetime64[ns]               94
# applicant_first_name                            object              270
# applicant_last_name                             object              291
# applicant_business_name                         object               38
# applicant_address_1                             object              238
# applicant_address_2                             object               65
# applicant_address_3                             object              119
# zone                                            object              167
# occupancy                                       object                2
# floor_area_la_building_code_definition          object               29
# census_tract                                    object              341
# council_district                                 int64               15
# latitude_longitude                              object              476
# applicant_relationship                          object               11
# existing_code                                  float64               14
# proposed_code                                  float64               12
#
#                                         # MISSING VALUES  \
# COLUMN
# assessor_book                                          0
# assessor_page                                          0
# assessor_parcel                                        0
# tract                                                  3
# block                                                384
# lot                                                    4
# reference_no_old_permit_no                           305
# pcis_permit_no                                         0
# status                                                 0
# status_date                                            0
# permit_type                                            0
# permit_sub_type                                        0
# permit_category                                        0
# project_number                                       495
# initiating_office                                      0
# issue_date                                             0
# address_start                                          0
# address_fraction_start                               494
# address_end                                            0
# address_fraction_end                                 482
# street_direction                                       8
# street_name                                            0
# street_suffix                                         11
# suffix_direction                                     496
# unit_range_start                                     396
# unit_range_end                                       490
# zip_code                                               0
# work_description                                     305
# valuation                                            342
# floor_area_la_zoning_code_definition                 465
# no_of_residential_dwelling_units                     485
# no_of_stories                                        467
# contractors_business_name                              0
# contractor_address                                    55
# contractor_city                                       60
# contractor_state                                      60
# license_type                                           0
# license_no                                             0
# principal_first_name                                  48
# principal_middle_name                                194
# principal_last_name                                   52
# license_expiration_date                               39
# applicant_first_name                                 116
# applicant_last_name                                  158
# applicant_business_name                              443
# applicant_address_1                                  227
# applicant_address_2                                  413
# applicant_address_3                                  229
# zone                                                   0
# occupancy                                            494
# floor_area_la_building_code_definition                92
# census_tract                                           0
# council_district                                       0
# latitude_longitude                                    21
# applicant_relationship                                14
# existing_code                                        379
# proposed_code                                        455
#
#                                                                              SAMPLE VALUE
# COLUMN
# assessor_book                                                                        5159
# assessor_page                                                                           6
# assessor_parcel                                                                       009
# tract                                                                            TR 37916
# block                                                                                  17
# lot                                                                                    40
# reference_no_old_permit_no                                                           18VN
# pcis_permit_no                                                          17041-90000-32881
# status                                                                     Permit Finaled
# status_date                                                           2018-04-30 00:00:00
# permit_type                                                             Bldg-Alter/Repair
# permit_sub_type                                                                Commercial
# permit_category                                                             No Plan Check
# project_number                                                                          5
# initiating_office                                                                   METRO
# issue_date                                                            2014-10-24 00:00:00
# address_start                                                                        1315
# address_fraction_start                                                                1/2
# address_end                                                                         17724
# address_fraction_end                                                                  1/2
# street_direction                                                                        S
# street_name                                                                  GARDEN GROVE
# street_suffix                                                                          ST
# suffix_direction                                                                     WEST
# unit_range_start                                                                     NO 6
# unit_range_end                                                                        1-8
# zip_code                                                                            90049
# work_description                        Reroof with 30 sqrs COMP SHINGLE roofing over ...
# valuation                                                                           51.00
# floor_area_la_zoning_code_definition                                                 1759
# no_of_residential_dwelling_units                                                       -2
# no_of_stories                                                                           1
# contractors_business_name                                            CORE FIRE PROTECTION
# contractor_address                                                1621 W 25TH STREET #251
# contractor_city                                                                 CALABASAS
# contractor_state                                                                       CA
# license_type                                                                          C20
# license_no                                                                         613692
# principal_first_name                                                               JOSEPH
# principal_middle_name                                                                DEAN
# principal_last_name                                                                MELVIN
# license_expiration_date                                               2015-09-30 00:00:00
# applicant_first_name                                                        ROBERTO RAMOS
# applicant_last_name                                                                 ARANA
# applicant_business_name                                        MUIR-CHASE PLUMBING CO INC
# applicant_address_1                                                     21040 NORDHOFF ST
# applicant_address_2                                                                   160
# applicant_address_3                                                            RESEDA, CA
# zone                                                                                C5-4D
# occupancy                                                                   R3 Occ. Group
# floor_area_la_building_code_definition                                                  0
# census_tract                                                                      2766.01
# council_district                                                                       12
# latitude_longitude                                                 (34.05136, -118.26616)
# applicant_relationship                                                         Contractor
# existing_code                                                                          23
# proposed_code                                                                          19

# %% [markdown]
# At the moment the only missing data of interest are *zip_code* and *latitude_longitude* coordinates, since these are necesary for mapping.

# %% [markdown]
# ### 1.2 Processing Missing Data
#
# ***Overview:***
# * 1.2.1 - Combine address columns into one columns: *full_address*<br>
#     - Correct *suffix_direction*
#     - Convert *zip_code* to string
#     - Concatenate to form *full_address*
# * 1.2.2 - Geocode missing *latitude_longitude* with *full_address*<br>
# * 1.2.3 - Split *latitude_longitude* into separate columns and convert to float values: *latitude*, *longitude*<br>
# <br>
# * Geocode missing *zip_code* with complete *latitude_longitude*<br>
# * Geocode any missing *full_address* with *latitude_longitude*<br>

# %% [markdown]
# #### 1.2.1 Concatenate *full_address*
#
# 1) Correct values *suffix_direction*.<br>
# 2) Convert *zip_code* to string.<br>
# 3) Concatenate to form a complete street address string.

# %%
# Truncate suffix_direction to first letter (N, S, E, W)
data['suffix_direction'] = data['suffix_direction'].str[0].fillna('')

# Convert zip_code to string
data['zip_code'] = data['zip_code'].fillna('').astype(str)

# Combine address columns to concatenate
address_columns = ["address_start", "street_direction", "street_name", "street_suffix", "suffix_direction",
                  "zip_code"]

# Concatenate address values
data['full_address'] = data[address_columns].fillna('').astype(str).apply(' '.join, axis=1).str.replace('  ', ' ')

# Replace empty strings with NaN values
data[address_columns] = data[address_columns].replace('', np.nan)

# %%
# Display
data[address_columns + ['full_address']].head()
# Out:
#    address_start street_direction street_name street_suffix suffix_direction  \
# 0           1823                S      THAYER           AVE              NaN
# 1           2122                W        54TH            ST              NaN
# 2            415                S  BURLINGTON           AVE              NaN
# 3            315                S      OCEANO            DR              NaN
# 4          13640                W      PIERCE            ST              NaN
#
#   zip_code                full_address
# 0    90025     1823 S THAYER AVE 90025
# 1    90062        2122 W 54TH ST 90062
# 2    90057  415 S BURLINGTON AVE 90057
# 3    90049       315 S OCEANO DR 90049
# 4    91331     13640 W PIERCE ST 91331

# %% [markdown]
# #### 1.2.2 Geocode missing *latitude_longitude*

# %%
# Extract rows missing in latitude_longitude
data_missing = data[data['latitude_longitude'].isnull()==1]

# Size
data_missing.shape
# Out:
# (21, 60)

# %%
data_missing
# Out:
#      assessor_book  assessor_page assessor_parcel  \
# 5             2219             27             052
# 113           2537              7             012
# 148           2656              5             160
# 161           5512              3             042
# 171           5586              7             007
# 237           5511              8             013
# 263           4319              2             060
# 264           7426             23             010
# 268           5527             31             014
# 275           5073              7             020
# 278           2615             22             040
# 315           2701              3             034
# 325           4333             15             ***
# 331           2146             28             ***
# 334           6049             30             029
# 368           5415             18             010
# 429           5064             28             016
# 460           5408             32             011
# 483           2162             19             ***
# 486           2209             23             018
# 489           4129             27             902
#
#                                                  tract block  \
# 5                                             TR 73820   NaN
# 113                                            TR 6026   NaN
# 148  SUBDIVISION NO. 1 OF THE PROPERTY OF THE PORTE...   NaN
# 161                                           TR 45628   NaN
# 171                                  LOPEZ VILLA TRACT   NaN
# 237                                           TR 10389   NaN
# 263                                           TR 30364   NaN
# 264                                            TR 4251   NaN
# 268                                            TR 6790   NaN
# 275                              THE W. G. NEVIN TRACT     6
# 278                                           TR 67511   NaN
# 315                                      TR 54153-02-C   NaN
# 325                                         TR 40327-C   NaN
# 331                                         TR 26030-C   NaN
# 334                                            TR 7953   NaN
# 368                                           TR 25130   NaN
# 429                                            TR 7129   NaN
# 460                                       ORD'S SURVEY    37
# 483                                         TR 23719-C   NaN
# 486                                           TR 15010   NaN
# 489                              RANCHO SAUSAL REDONDO   NaN
#
#                     lot reference_no_old_permit_no     pcis_permit_no  \
# 5                    52                  18VN77133  17010-20000-02747
# 113                 121                        NaN  17041-20000-01717
# 148  1  SEC 21 T2N R15W                        NaN  18042-20000-08835
# 161                LT 7                  17LA81020  16016-10001-25903
# 171                   8                        NaN  18042-40000-25623
# 237                 120                        NaN  17042-20000-32019
# 263                   4                        NaN  18042-10001-07950
# 264                 117                        NaN  18044-40000-13741
# 268                 313                       16LA  15042-20000-13885
# 275                   2                        NaN  18046-90000-02205
# 278                   6                        NaN  14041-20000-21926
# 315                LT 1                  13VN68148  13010-20001-02755
# 325                LT 1                        NaN  18041-70000-36451
# 331                   3                  19LA22678  18016-10000-35406
# 334                 131                  18SL63942  17010-10000-04016
# 368                  25                        NaN  18041-10000-35132
# 429                  53                        NaN  16041-10001-04032
# 460                   3                        NaN  17042-10000-08516
# 483                LT 1                        NaN  13046-90000-01071
# 486                 200                        NaN  17041-20000-11885
# 489               LT 37                        NaN  18043-10001-00176
#
#                status status_date        permit_type         permit_sub_type  \
# 5         CofO Issued  2019-04-05           Bldg-New  1 or 2 Family Dwelling
# 113    Permit Finaled  2017-04-25         Electrical  1 or 2 Family Dwelling
# 148            Issued  2018-04-10           Plumbing  1 or 2 Family Dwelling
# 161            Issued  2017-04-24  Bldg-Alter/Repair              Commercial
# 171            Issued  2018-10-23           Plumbing               Apartment
# 237    Permit Finaled  2018-07-30           Plumbing               Apartment
# 263    Permit Finaled  2018-05-11           Plumbing              Commercial
# 264  Refund Completed  2019-03-11               HVAC  1 or 2 Family Dwelling
# 268    Permit Expired  2018-09-25           Plumbing              Commercial
# 275            Issued  2018-12-21           Elevator               Apartment
# 278    Permit Finaled  2015-08-18         Electrical  1 or 2 Family Dwelling
# 315    Permit Finaled  2014-01-15  Bldg-Alter/Repair               Apartment
# 325    Permit Finaled  2018-11-14         Electrical               Apartment
# 331            Issued  2019-04-11  Bldg-Alter/Repair               Apartment
# 334            Issued  2018-04-30           Bldg-New  1 or 2 Family Dwelling
# 368     Permit Closed  2018-09-18         Electrical       Special Equipment
# 429    Permit Finaled  2017-03-16         Electrical  1 or 2 Family Dwelling
# 460    Permit Finaled  2017-08-31           Plumbing              Commercial
# 483    Permit Finaled  2013-08-27           Elevator               Apartment
# 486    Permit Finaled  2017-05-10         Electrical  1 or 2 Family Dwelling
# 489    Permit Finaled  2018-06-29     Fire Sprinkler              Commercial
#
#     permit_category  project_number  event_code initiating_office issue_date  \
# 5        Plan Check             NaN         NaN          VAN NUYS 2018-09-21
# 113   No Plan Check             NaN         NaN          VAN NUYS 2017-01-18
# 148   No Plan Check             NaN         NaN          VAN NUYS 2018-04-10
# 161      Plan Check             NaN         NaN             METRO 2017-04-24
# 171   No Plan Check             NaN         NaN          SANPEDRO 2018-10-23
# 237   No Plan Check             NaN         NaN          VAN NUYS 2017-12-28
# 263   No Plan Check             NaN         NaN             METRO 2018-05-08
# 264   No Plan Check             NaN         NaN          SANPEDRO 2018-11-08
# 268      Plan Check             NaN         NaN          VAN NUYS 2016-06-13
# 275   No Plan Check             NaN         NaN          INTERNET 2018-12-21
# 278   No Plan Check             NaN         NaN          VAN NUYS 2014-08-13
# 315      Plan Check             NaN         NaN          VAN NUYS 2013-12-05
# 325   No Plan Check             NaN         NaN          SOUTH LA 2018-09-24
# 331      Plan Check             NaN         NaN             METRO 2019-04-11
# 334      Plan Check             NaN         NaN             METRO 2018-04-30
# 368   No Plan Check             NaN         NaN             METRO 2018-09-13
# 429   No Plan Check             NaN         NaN             METRO 2017-03-07
# 460   No Plan Check             NaN         NaN             METRO 2017-04-18
# 483   No Plan Check             NaN         NaN          INTERNET 2013-08-09
# 486   No Plan Check             NaN         NaN          VAN NUYS 2017-04-12
# 489   No Plan Check             5.0         NaN             METRO 2018-06-20
#
#      address_start address_fraction_start  address_end address_fraction_end  \
# 5             7111                    NaN         7111                  NaN
# 113          12453                    NaN        12453                  NaN
# 148           9842                    NaN         9842                  NaN
# 161            101                    NaN          101                  NaN
# 171           1956                    NaN         1956                  NaN
# 237            135                    1/2          135                  1/2
# 263           1925                    NaN         1925                  NaN
# 264           1440                    NaN         1440                  NaN
# 268            465                    NaN          465                  NaN
# 275           1511                    NaN         1511                  NaN
# 278          10846                    NaN        10846                  NaN
# 315          20450                    NaN        20450                  NaN
# 325            869                    NaN          869                  NaN
# 331           6204                    NaN         6212                  1/2
# 334           1122                    NaN         1122                  1/2
# 368           1000                    NaN         1000                  NaN
# 429           2307                    NaN         2309                  NaN
# 460            833                    NaN          833                  NaN
# 483           5339                    NaN         5339                  NaN
# 486           8060                    NaN         8060                  NaN
# 489            401                    NaN          401                  NaN
#
#     street_direction   street_name street_suffix suffix_direction  \
# 5                  N        MARISA            RD              NaN
# 113                W      BROMWICH            ST              NaN
# 148                N        LASSEN          ROAD              NaN
# 161                S     THE GROVE            DR              NaN
# 171                N        CARMEN           AVE              NaN
# 237                N        HARPER           AVE              NaN
# 263              NaN  CENTURY PARK           NaN                E
# 264              NaN        GAMBLE           AVE              NaN
# 268                N       FAIRFAX           AVE              NaN
# 275                S    ST ANDREWS            PL              NaN
# 278                N        BONITA          LANE              NaN
# 315                W      SORRENTO          LANE              NaN
# 325                S       WOOSTER            ST              NaN
# 331                N         SHOUP           AVE              NaN
# 334                E          94TH            ST              NaN
# 368                W    VIN SCULLY           AVE              NaN
# 429                S     SPAULDING           AVE              NaN
# 460                N      BROADWAY           NaN              NaN
# 483                N     NEWCASTLE           AVE              NaN
# 486                N        WISNER           AVE              NaN
# 489              NaN         WORLD           WAY              NaN
#
#     unit_range_start unit_range_end zip_code  \
# 5                NaN            NaN    91405
# 113              NaN            NaN    91331
# 148           LOT 14            NaN    91345
# 161              NaN            NaN    90036
# 171              NaN            NaN    90068
# 237              NaN            NaN    90048
# 263       18TH FLOOR            NaN    90067
# 264              NaN            NaN    90744
# 268              NaN            NaN    90036
# 275             1-45            NaN    90019
# 278              NaN            NaN    91345
# 315              NaN            NaN    91326
# 325              101            NaN    90035
# 331              NaN         BLDG 8    91367
# 334              NaN            NaN    90002
# 368              NaN            NaN    90026
# 429              NaN            NaN    90016
# 460              NaN            NaN    90012
# 483            NO 35            NaN    91316
# 486              NaN            NaN    91402
# 489              NaN            NaN    90045
#
#                                       work_description  valuation  \
# 5                     NEW SFD/GARAGE - PLAN 1A, LOT-52  196660.00
# 113                                                NaN        NaN
# 148                                                NaN        NaN
# 161  Supplemental to permit #16016-10000-25903 and ...   50000.00
# 171                                                NaN        NaN
# 237                                                NaN        NaN
# 263                                                NaN        NaN
# 264                                                NaN        NaN
# 268  INSTALLATION OF POTABLE WATER, WASTE & VENT AN...        NaN
# 275                                                NaN        NaN
# 278                                                NaN        NaN
# 315  SUPPLEMENTAL PERMIT TO ADD PROVIDED PARKING FO...       0.00
# 325                                                NaN        NaN
# 331  SOFT STORY RETROFIT PER LABC CH 93. INSTALL (N...   10000.00
# 334  NEW TWO STORY, 77'3"x37'2"  DUPLEX WITH ATTACH...  300000.00
# 368                                                NaN        NaN
# 429                                                NaN        NaN
# 460                                                NaN        NaN
# 483                                                NaN        NaN
# 486                                                NaN        NaN
# 489                                                NaN        NaN
#
#     floor_area_la_zoning_code_definition  no_of_residential_dwelling_units  \
# 5                                   1560                               1.0
# 113                                  NaN                               NaN
# 148                                  NaN                               NaN
# 161                                  NaN                               NaN
# 171                                  NaN                               NaN
# 237                                  NaN                               NaN
# 263                                  NaN                               NaN
# 264                                  NaN                               NaN
# 268                                  NaN                               NaN
# 275                                  NaN                               NaN
# 278                                  NaN                               NaN
# 315                                  NaN                               NaN
# 325                                  NaN                               NaN
# 331                                  NaN                               NaN
# 334                                 3560                               2.0
# 368                                  NaN                               NaN
# 429                                  NaN                               NaN
# 460                                  NaN                               NaN
# 483                                  NaN                               NaN
# 486                                  NaN                               NaN
# 489                                  NaN                               NaN
#
#      no_of_accessory_dwelling_units  no_of_stories  \
# 5                               NaN            2.0
# 113                             NaN            NaN
# 148                             NaN            NaN
# 161                             NaN            NaN
# 171                             NaN            NaN
# 237                             NaN            NaN
# 263                             NaN            NaN
# 264                             NaN            NaN
# 268                             NaN            NaN
# 275                             NaN            NaN
# 278                             NaN            NaN
# 315                             NaN            NaN
# 325                             NaN            NaN
# 331                             NaN            3.0
# 334                             NaN            2.0
# 368                             NaN            NaN
# 429                             NaN            NaN
# 460                             NaN            NaN
# 483                             NaN            NaN
# 486                             NaN            NaN
# 489                             NaN            NaN
#
#               contractors_business_name            contractor_address  \
# 5                         OWNER-BUILDER                           NaN
# 113                    MSP CONSTRUCTION              7175 DE PALMA ST
# 148   SEWER AND PIPELINE CONTRACTOR INC            4518 S WESTERN AVE
# 161                    NEXT VENTURE INC           560 RIVERDALE DRIVE
# 171        A 1 COPPER REPIPE SPECIALIST     1082 E ARTESIA BLVD STE A
# 237                 ARNOLD'S REMODELING         8146 LONGRIDGE AVENUE
# 263          MUIR-CHASE PLUMBING CO INC            4530 BRAZIL STREET
# 264             PRECISE AIR SYSTEMS INC                 P O BOX 39609
# 268                   FREE CREATION INC   5478 WILSHIRE BLVD UNIT 214
# 275   CONSOLIDATED ELEVATOR COMPANY INC         964 E BADILLO ST #303
# 278                       OWNER-BUILDER                           NaN
# 315              SHAPELL INDUSTRIES INC  8383 WILSHIRE BLVD SUITE 700
# 325                 RAW DEVELOPMENT INC    4859 W SLAUSON AVENUE #377
# 331                    BUTLAND E H CORP           6100 YOLANDA AVENUE
# 334                 CASTRO PLUMBING INC            221 W 103RD STREET
# 368                       OWNER-BUILDER                           NaN
# 429               SOLARCITY CORPORATION            3055 CLEARVIEW WAY
# 460  EMPIRE BUILDING AND REMODELING INC          133 PRINCETON AVENUE
# 483                     ATOMIC ELEVATOR               8342 JADE DRIVE
# 486                       OWNER-BUILDER                           NaN
# 489           MYERS AND SONS - GRIFFITH       12200 BLOOMFIELD AVENUE
#
#       contractor_city contractor_state license_type  license_no  \
# 5                 NaN              NaN           NA           0
# 113            DOWNEY               CA            B      789577
# 148       LOS ANGELES               CA          C36      904635
# 161          GLENDALE               CA            B      749452
# 171        LONG BEACH               CA          C36      883229
# 237   NORTH HOLLYWOOD               CA            B      929036
# 263       LOS ANGELES               CA          C36      539835
# 264       LOS ANGELES               CA          C20      428900
# 268       LOS ANGELES               CA            B     1003352
# 275            COVINA               CA          C11     1019792
# 278               NaN              NaN           NA           0
# 315     BEVERLY HILLS               CA            B      315237
# 325       LOS ANGELES               CA            B      989611
# 331            RESEDA               CA            B      831933
# 334       LOS ANGELES               CA            B      961554
# 368               NaN              NaN           NA           0
# 429         SAN MATEO               CA          C10      888104
# 460         CLAREMONT               CA            B      988084
# 483         ALTA LOMA               CA          C11      956996
# 486               NaN              NaN           NA           0
# 489  SANTA FE SPRINGS               CA            A     1019597
#
#     principal_first_name principal_middle_name principal_last_name  \
# 5                    NaN                   NaN                 NaN
# 113               MIGUEL                   NaN             SOLTERO
# 148               MANUEL               SANTANA              CHAMUL
# 161                 CARL                  JUAN             FROMMER
# 171              RICARDO             HERNANDEZ             AMEZCUA
# 237                 JOSE               ARNOLDO             ORANTES
# 263                GRANT                 DRAKE                MUIR
# 264                 FRED                   NaN          KHACHEKIAN
# 268                  BEN                   NaN              KISLER
# 275              MICHAEL                JOSEPH               BROWN
# 278                  NaN                   NaN                 NaN
# 315              VINCENT               ANTHONY               ROSSI
# 325               THOMAS                   NaN               REESE
# 331                DAVID                 ALLAN            NOWACZYK
# 334             EZEQUIEL                FRANCO            VILLEGAS
# 368                  NaN                   NaN                 NaN
# 429             BENJAMIN              JEREMIAH                 LIU
# 460              ELEAZAR                   NaN             BECERRA
# 483                AARON           CHRISTOPHER              SEMLER
# 486                  NaN                   NaN                 NaN
# 489                  NaN                   NaN                 NaN
#
#     license_expiration_date applicant_first_name applicant_last_name  \
# 5                       NaT                DAVID               LELIE
# 113              2018-09-30                  NaN                 NaN
# 148              2019-10-31              URIU  &          ASSOCIATES
# 161              2018-05-31                JENNY                DIAZ
# 171              2020-08-31              RICARDO             AMEZCUA
# 237              2019-02-28                  NaN                 NaN
# 263              2018-08-31              PHILLIP                HONS
# 264              2020-10-31                DIANA              OLIVAS
# 268              2017-05-31           TED MORENO                 NaN
# 275              2018-10-31                DAVID            SANDOVAL
# 278              2000-01-01                 ELSA                 NaN
# 315              2014-09-30                VANDA                 NaN
# 325              2020-01-31               THOMAS               REESE
# 331              2020-02-29                 DAVE            NOWACZYK
# 334              2019-05-31              MYCHAEL              MEHRIZ
# 368              2009-01-01                DAVID              EDFORD
# 429              2017-12-31                  NaN                 NaN
# 460              2017-10-31                  NaN                 NaN
# 483              2015-01-31                AARON              SEMLER
# 486              2009-01-01                  NaN                 NaN
# 489              2018-10-31               ROBERT                 NaN
#
#         applicant_business_name    applicant_address_1 applicant_address_2  \
# 5                           NaN   25152 SPRINGFIELD CT                #180
# 113                         NaN                    NaN                 NaN
# 148                         NaN     830 S GLENDALE AVE                 NaN
# 161                         NaN       1300 DOVE STREET                 100
# 171                         NaN                    NaN                 NaN
# 237                         NaN                    NaN                 NaN
# 263  MUIR-CHASE PLUMBING CO INC                    NaN                 NaN
# 264                         NaN                    NaN                 NaN
# 268                         NaN  9111 MORNING GLOW WAY                 NaN
# 275                         NaN       964 E BADILLO ST                 303
# 278                         NaN                    NaN                 NaN
# 315                         NaN        11280 CORBIN AV                 NaN
# 325                         NaN                    NaN                 NaN
# 331                         NaN                    NaN                 NaN
# 334                         NaN        7117 ALVERN ST.                E126
# 368                         NaN                    NaN                 NaN
# 429                         NaN                    NaN                 NaN
# 460                         NaN                    NaN                 NaN
# 483                         NaN           8342 JADE DR                 NaN
# 486                         NaN                    NaN                 NaN
# 489                         NaN                    NaN                 NaN
#
#       applicant_address_3           zone occupancy  \
# 5            VALENCIA, CA    (T)(Q)RD2-1       NaN
# 113                   NaN      R1-1-CUGU       NaN
# 148          GLENDALE, CA          RD2-1       NaN
# 161     NEWPORT BEACH, CA     (T)C2-2D-O       NaN
# 171                   NaN         R3-1XL       NaN
# 237                   NaN      RD1.5-1-O       NaN
# 263                   NaN         C2-2-O       NaN
# 264                   NaN  R1-1XL-O-CUGU       NaN
# 268        SUN VALLEY, CA         C2-1VL       NaN
# 275            COVINA, CA        [Q]R4-1       NaN
# 278                   NaN       (Q)RD6-1       NaN
# 315            NORTHRIDGE       [T]C4-2D       NaN
# 325                   NaN      [Q]R4-1-O       NaN
# 331                   NaN        [Q]R3-1       NaN
# 334       LOS ANGELES, CA          RD2-1       NaN
# 368                   NaN         A1-1XL       NaN
# 429                   NaN        RD1.5-1       NaN
# 460                   NaN           C2-2       NaN
# 483  RANCHO CUCAMONGA, CA           R3-1       NaN
# 486                   NaN           R1-1       NaN
# 489                   NaN            LAX       NaN
#
#     floor_area_la_building_code_definition census_tract  council_district  \
# 5                                     1985      1278.03                 6
# 113                                      0      1047.03                 7
# 148                                      0      1171.02                 7
# 161                                    NaN      2145.01                 4
# 171                                      0      1895.00                 4
# 237                                      0      2146.00                 5
# 263                                      0      2679.01                 5
# 264                                      0      2941.20                15
# 268                                      0      1945.00                 5
# 275                                      0      2213.04                10
# 278                                      0      1094.00                 7
# 315                                    NaN      1082.02                12
# 325                                      0      2164.02                 5
# 331                                    NaN      1351.14                 3
# 334                                   3645      2407.00                 9
# 368                                      0      1977.00                 1
# 429                                      0      2703.00                10
# 460                                      0      2071.03                 1
# 483                                      0      1395.03                 5
# 486                                      0      1200.10                 6
# 489                                      0      9800.28                11
#
#     latitude_longitude applicant_relationship  existing_code  proposed_code  \
# 5                  NaN        Agent for Owner            NaN            1.0
# 113                NaN                    NaN            NaN            NaN
# 148                NaN              Architect            NaN            NaN
# 161                NaN        Agent for Owner           21.0            NaN
# 171                NaN             Contractor            NaN            NaN
# 237                NaN                    NaN            NaN            NaN
# 263                NaN   Agent for Contractor            NaN            NaN
# 264                NaN   Agent for Contractor            1.0            NaN
# 268                NaN        Agent for Owner            NaN            NaN
# 275                NaN          Net Applicant            NaN            NaN
# 278                NaN   Agent for Contractor            NaN            NaN
# 315                NaN        Agent for Owner            7.0            NaN
# 325                NaN             Contractor            NaN            NaN
# 331                NaN        Agent for Owner           35.0            NaN
# 334                NaN        Agent for Owner            NaN            2.0
# 368                NaN        Agent for Owner            NaN            NaN
# 429                NaN             Contractor            NaN            NaN
# 460                NaN                    NaN            NaN            NaN
# 483                NaN          Net Applicant            NaN            NaN
# 486                NaN             Owner-Bldr            NaN            NaN
# 489                NaN   Agent for Contractor            NaN            NaN
#
#                     full_address
# 5         7111 N MARISA RD 91405
# 113    12453 W BROMWICH ST 91331
# 148     9842 N LASSEN ROAD 91345
# 161     101 S THE GROVE DR 90036
# 171      1956 N CARMEN AVE 90068
# 237       135 N HARPER AVE 90048
# 263    1925 CENTURY PARK E 90067
# 264        1440 GAMBLE AVE 90744
# 268      465 N FAIRFAX AVE 90036
# 275   1511 S ST ANDREWS PL 90019
# 278    10846 N BONITA LANE 91345
# 315  20450 W SORRENTO LANE 91326
# 325       869 S WOOSTER ST 90035
# 331       6204 N SHOUP AVE 91367
# 334         1122 E 94TH ST 90002
# 368  1000 W VIN SCULLY AVE 90026
# 429   2307 S SPAULDING AVE 90016
# 460        833 N BROADWAY  90012
# 483   5339 N NEWCASTLE AVE 91316
# 486      8060 N WISNER AVE 91402
# 489          401 WORLD WAY 90045

# %%
# Create helper function to geocode missing latitude_longitude values
def geocode(address, key, agent, timeout=None):
    
    """
    Uses GoogleMaps API to geocode address strings to lat/long coordinates. RateLimiter is to 
    avoid timeout errors. If an address cannot be geocoded it is left as NaN. Use of GoogleMaps 
    API incurs a charge at $0.005 per request.
    
    
    """
    
    if address:
        # Initializes GoogleMaps geocoder
        geolocator = GoogleV3(api_key=key, 
                              user_agent=agent, 
                              timeout=timeout)

        # Adds Rate Limiter to space out requests
        geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

        # Geocode address input and format for dataframe
        location = geolocator.geocode(address)
        #print(address, location.latitude)
        
        latitude, longitude = round(location.latitude, 7), round(location.longitude, 7)
        
        return latitude, longitude
    else:
        return np.nan

# %%
# Calculate cost
cost = len(data_missing) * 0.005
print("Cost for geocoding {} addresses is ${:.2f}.".format(len(data_missing), cost))

# Geocode missing coordinates using full addresses
data_missing['latitude_longitude'] = data_missing['full_address'].apply(geocode, args=(GOOGLE_API_KEY, 
                                                                                       "permits-data"))

# Update dataframe
data.update(data_missing)
# Out:
# Cost for geocoding 21 addresses is $0.10.
# /Users/gregory/anaconda3/envs/permits-data-env/lib/python3.5/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
data_missing
# Out:
#      assessor_book  assessor_page assessor_parcel  \
# 5             2219             27             052
# 113           2537              7             012
# 148           2656              5             160
# 161           5512              3             042
# 171           5586              7             007
# 237           5511              8             013
# 263           4319              2             060
# 264           7426             23             010
# 268           5527             31             014
# 275           5073              7             020
# 278           2615             22             040
# 315           2701              3             034
# 325           4333             15             ***
# 331           2146             28             ***
# 334           6049             30             029
# 368           5415             18             010
# 429           5064             28             016
# 460           5408             32             011
# 483           2162             19             ***
# 486           2209             23             018
# 489           4129             27             902
#
#                                                  tract block  \
# 5                                             TR 73820   NaN
# 113                                            TR 6026   NaN
# 148  SUBDIVISION NO. 1 OF THE PROPERTY OF THE PORTE...   NaN
# 161                                           TR 45628   NaN
# 171                                  LOPEZ VILLA TRACT   NaN
# 237                                           TR 10389   NaN
# 263                                           TR 30364   NaN
# 264                                            TR 4251   NaN
# 268                                            TR 6790   NaN
# 275                              THE W. G. NEVIN TRACT     6
# 278                                           TR 67511   NaN
# 315                                      TR 54153-02-C   NaN
# 325                                         TR 40327-C   NaN
# 331                                         TR 26030-C   NaN
# 334                                            TR 7953   NaN
# 368                                           TR 25130   NaN
# 429                                            TR 7129   NaN
# 460                                       ORD'S SURVEY    37
# 483                                         TR 23719-C   NaN
# 486                                           TR 15010   NaN
# 489                              RANCHO SAUSAL REDONDO   NaN
#
#                     lot reference_no_old_permit_no     pcis_permit_no  \
# 5                    52                  18VN77133  17010-20000-02747
# 113                 121                        NaN  17041-20000-01717
# 148  1  SEC 21 T2N R15W                        NaN  18042-20000-08835
# 161                LT 7                  17LA81020  16016-10001-25903
# 171                   8                        NaN  18042-40000-25623
# 237                 120                        NaN  17042-20000-32019
# 263                   4                        NaN  18042-10001-07950
# 264                 117                        NaN  18044-40000-13741
# 268                 313                       16LA  15042-20000-13885
# 275                   2                        NaN  18046-90000-02205
# 278                   6                        NaN  14041-20000-21926
# 315                LT 1                  13VN68148  13010-20001-02755
# 325                LT 1                        NaN  18041-70000-36451
# 331                   3                  19LA22678  18016-10000-35406
# 334                 131                  18SL63942  17010-10000-04016
# 368                  25                        NaN  18041-10000-35132
# 429                  53                        NaN  16041-10001-04032
# 460                   3                        NaN  17042-10000-08516
# 483                LT 1                        NaN  13046-90000-01071
# 486                 200                        NaN  17041-20000-11885
# 489               LT 37                        NaN  18043-10001-00176
#
#                status status_date        permit_type         permit_sub_type  \
# 5         CofO Issued  2019-04-05           Bldg-New  1 or 2 Family Dwelling
# 113    Permit Finaled  2017-04-25         Electrical  1 or 2 Family Dwelling
# 148            Issued  2018-04-10           Plumbing  1 or 2 Family Dwelling
# 161            Issued  2017-04-24  Bldg-Alter/Repair              Commercial
# 171            Issued  2018-10-23           Plumbing               Apartment
# 237    Permit Finaled  2018-07-30           Plumbing               Apartment
# 263    Permit Finaled  2018-05-11           Plumbing              Commercial
# 264  Refund Completed  2019-03-11               HVAC  1 or 2 Family Dwelling
# 268    Permit Expired  2018-09-25           Plumbing              Commercial
# 275            Issued  2018-12-21           Elevator               Apartment
# 278    Permit Finaled  2015-08-18         Electrical  1 or 2 Family Dwelling
# 315    Permit Finaled  2014-01-15  Bldg-Alter/Repair               Apartment
# 325    Permit Finaled  2018-11-14         Electrical               Apartment
# 331            Issued  2019-04-11  Bldg-Alter/Repair               Apartment
# 334            Issued  2018-04-30           Bldg-New  1 or 2 Family Dwelling
# 368     Permit Closed  2018-09-18         Electrical       Special Equipment
# 429    Permit Finaled  2017-03-16         Electrical  1 or 2 Family Dwelling
# 460    Permit Finaled  2017-08-31           Plumbing              Commercial
# 483    Permit Finaled  2013-08-27           Elevator               Apartment
# 486    Permit Finaled  2017-05-10         Electrical  1 or 2 Family Dwelling
# 489    Permit Finaled  2018-06-29     Fire Sprinkler              Commercial
#
#     permit_category  project_number  event_code initiating_office issue_date  \
# 5        Plan Check             NaN         NaN          VAN NUYS 2018-09-21
# 113   No Plan Check             NaN         NaN          VAN NUYS 2017-01-18
# 148   No Plan Check             NaN         NaN          VAN NUYS 2018-04-10
# 161      Plan Check             NaN         NaN             METRO 2017-04-24
# 171   No Plan Check             NaN         NaN          SANPEDRO 2018-10-23
# 237   No Plan Check             NaN         NaN          VAN NUYS 2017-12-28
# 263   No Plan Check             NaN         NaN             METRO 2018-05-08
# 264   No Plan Check             NaN         NaN          SANPEDRO 2018-11-08
# 268      Plan Check             NaN         NaN          VAN NUYS 2016-06-13
# 275   No Plan Check             NaN         NaN          INTERNET 2018-12-21
# 278   No Plan Check             NaN         NaN          VAN NUYS 2014-08-13
# 315      Plan Check             NaN         NaN          VAN NUYS 2013-12-05
# 325   No Plan Check             NaN         NaN          SOUTH LA 2018-09-24
# 331      Plan Check             NaN         NaN             METRO 2019-04-11
# 334      Plan Check             NaN         NaN             METRO 2018-04-30
# 368   No Plan Check             NaN         NaN             METRO 2018-09-13
# 429   No Plan Check             NaN         NaN             METRO 2017-03-07
# 460   No Plan Check             NaN         NaN             METRO 2017-04-18
# 483   No Plan Check             NaN         NaN          INTERNET 2013-08-09
# 486   No Plan Check             NaN         NaN          VAN NUYS 2017-04-12
# 489   No Plan Check             5.0         NaN             METRO 2018-06-20
#
#      address_start address_fraction_start  address_end address_fraction_end  \
# 5             7111                    NaN         7111                  NaN
# 113          12453                    NaN        12453                  NaN
# 148           9842                    NaN         9842                  NaN
# 161            101                    NaN          101                  NaN
# 171           1956                    NaN         1956                  NaN
# 237            135                    1/2          135                  1/2
# 263           1925                    NaN         1925                  NaN
# 264           1440                    NaN         1440                  NaN
# 268            465                    NaN          465                  NaN
# 275           1511                    NaN         1511                  NaN
# 278          10846                    NaN        10846                  NaN
# 315          20450                    NaN        20450                  NaN
# 325            869                    NaN          869                  NaN
# 331           6204                    NaN         6212                  1/2
# 334           1122                    NaN         1122                  1/2
# 368           1000                    NaN         1000                  NaN
# 429           2307                    NaN         2309                  NaN
# 460            833                    NaN          833                  NaN
# 483           5339                    NaN         5339                  NaN
# 486           8060                    NaN         8060                  NaN
# 489            401                    NaN          401                  NaN
#
#     street_direction   street_name street_suffix suffix_direction  \
# 5                  N        MARISA            RD              NaN
# 113                W      BROMWICH            ST              NaN
# 148                N        LASSEN          ROAD              NaN
# 161                S     THE GROVE            DR              NaN
# 171                N        CARMEN           AVE              NaN
# 237                N        HARPER           AVE              NaN
# 263              NaN  CENTURY PARK           NaN                E
# 264              NaN        GAMBLE           AVE              NaN
# 268                N       FAIRFAX           AVE              NaN
# 275                S    ST ANDREWS            PL              NaN
# 278                N        BONITA          LANE              NaN
# 315                W      SORRENTO          LANE              NaN
# 325                S       WOOSTER            ST              NaN
# 331                N         SHOUP           AVE              NaN
# 334                E          94TH            ST              NaN
# 368                W    VIN SCULLY           AVE              NaN
# 429                S     SPAULDING           AVE              NaN
# 460                N      BROADWAY           NaN              NaN
# 483                N     NEWCASTLE           AVE              NaN
# 486                N        WISNER           AVE              NaN
# 489              NaN         WORLD           WAY              NaN
#
#     unit_range_start unit_range_end zip_code  \
# 5                NaN            NaN    91405
# 113              NaN            NaN    91331
# 148           LOT 14            NaN    91345
# 161              NaN            NaN    90036
# 171              NaN            NaN    90068
# 237              NaN            NaN    90048
# 263       18TH FLOOR            NaN    90067
# 264              NaN            NaN    90744
# 268              NaN            NaN    90036
# 275             1-45            NaN    90019
# 278              NaN            NaN    91345
# 315              NaN            NaN    91326
# 325              101            NaN    90035
# 331              NaN         BLDG 8    91367
# 334              NaN            NaN    90002
# 368              NaN            NaN    90026
# 429              NaN            NaN    90016
# 460              NaN            NaN    90012
# 483            NO 35            NaN    91316
# 486              NaN            NaN    91402
# 489              NaN            NaN    90045
#
#                                       work_description  valuation  \
# 5                     NEW SFD/GARAGE - PLAN 1A, LOT-52  196660.00
# 113                                                NaN        NaN
# 148                                                NaN        NaN
# 161  Supplemental to permit #16016-10000-25903 and ...   50000.00
# 171                                                NaN        NaN
# 237                                                NaN        NaN
# 263                                                NaN        NaN
# 264                                                NaN        NaN
# 268  INSTALLATION OF POTABLE WATER, WASTE & VENT AN...        NaN
# 275                                                NaN        NaN
# 278                                                NaN        NaN
# 315  SUPPLEMENTAL PERMIT TO ADD PROVIDED PARKING FO...       0.00
# 325                                                NaN        NaN
# 331  SOFT STORY RETROFIT PER LABC CH 93. INSTALL (N...   10000.00
# 334  NEW TWO STORY, 77'3"x37'2"  DUPLEX WITH ATTACH...  300000.00
# 368                                                NaN        NaN
# 429                                                NaN        NaN
# 460                                                NaN        NaN
# 483                                                NaN        NaN
# 486                                                NaN        NaN
# 489                                                NaN        NaN
#
#     floor_area_la_zoning_code_definition  no_of_residential_dwelling_units  \
# 5                                   1560                               1.0
# 113                                  NaN                               NaN
# 148                                  NaN                               NaN
# 161                                  NaN                               NaN
# 171                                  NaN                               NaN
# 237                                  NaN                               NaN
# 263                                  NaN                               NaN
# 264                                  NaN                               NaN
# 268                                  NaN                               NaN
# 275                                  NaN                               NaN
# 278                                  NaN                               NaN
# 315                                  NaN                               NaN
# 325                                  NaN                               NaN
# 331                                  NaN                               NaN
# 334                                 3560                               2.0
# 368                                  NaN                               NaN
# 429                                  NaN                               NaN
# 460                                  NaN                               NaN
# 483                                  NaN                               NaN
# 486                                  NaN                               NaN
# 489                                  NaN                               NaN
#
#      no_of_accessory_dwelling_units  no_of_stories  \
# 5                               NaN            2.0
# 113                             NaN            NaN
# 148                             NaN            NaN
# 161                             NaN            NaN
# 171                             NaN            NaN
# 237                             NaN            NaN
# 263                             NaN            NaN
# 264                             NaN            NaN
# 268                             NaN            NaN
# 275                             NaN            NaN
# 278                             NaN            NaN
# 315                             NaN            NaN
# 325                             NaN            NaN
# 331                             NaN            3.0
# 334                             NaN            2.0
# 368                             NaN            NaN
# 429                             NaN            NaN
# 460                             NaN            NaN
# 483                             NaN            NaN
# 486                             NaN            NaN
# 489                             NaN            NaN
#
#               contractors_business_name            contractor_address  \
# 5                         OWNER-BUILDER                           NaN
# 113                    MSP CONSTRUCTION              7175 DE PALMA ST
# 148   SEWER AND PIPELINE CONTRACTOR INC            4518 S WESTERN AVE
# 161                    NEXT VENTURE INC           560 RIVERDALE DRIVE
# 171        A 1 COPPER REPIPE SPECIALIST     1082 E ARTESIA BLVD STE A
# 237                 ARNOLD'S REMODELING         8146 LONGRIDGE AVENUE
# 263          MUIR-CHASE PLUMBING CO INC            4530 BRAZIL STREET
# 264             PRECISE AIR SYSTEMS INC                 P O BOX 39609
# 268                   FREE CREATION INC   5478 WILSHIRE BLVD UNIT 214
# 275   CONSOLIDATED ELEVATOR COMPANY INC         964 E BADILLO ST #303
# 278                       OWNER-BUILDER                           NaN
# 315              SHAPELL INDUSTRIES INC  8383 WILSHIRE BLVD SUITE 700
# 325                 RAW DEVELOPMENT INC    4859 W SLAUSON AVENUE #377
# 331                    BUTLAND E H CORP           6100 YOLANDA AVENUE
# 334                 CASTRO PLUMBING INC            221 W 103RD STREET
# 368                       OWNER-BUILDER                           NaN
# 429               SOLARCITY CORPORATION            3055 CLEARVIEW WAY
# 460  EMPIRE BUILDING AND REMODELING INC          133 PRINCETON AVENUE
# 483                     ATOMIC ELEVATOR               8342 JADE DRIVE
# 486                       OWNER-BUILDER                           NaN
# 489           MYERS AND SONS - GRIFFITH       12200 BLOOMFIELD AVENUE
#
#       contractor_city contractor_state license_type  license_no  \
# 5                 NaN              NaN           NA           0
# 113            DOWNEY               CA            B      789577
# 148       LOS ANGELES               CA          C36      904635
# 161          GLENDALE               CA            B      749452
# 171        LONG BEACH               CA          C36      883229
# 237   NORTH HOLLYWOOD               CA            B      929036
# 263       LOS ANGELES               CA          C36      539835
# 264       LOS ANGELES               CA          C20      428900
# 268       LOS ANGELES               CA            B     1003352
# 275            COVINA               CA          C11     1019792
# 278               NaN              NaN           NA           0
# 315     BEVERLY HILLS               CA            B      315237
# 325       LOS ANGELES               CA            B      989611
# 331            RESEDA               CA            B      831933
# 334       LOS ANGELES               CA            B      961554
# 368               NaN              NaN           NA           0
# 429         SAN MATEO               CA          C10      888104
# 460         CLAREMONT               CA            B      988084
# 483         ALTA LOMA               CA          C11      956996
# 486               NaN              NaN           NA           0
# 489  SANTA FE SPRINGS               CA            A     1019597
#
#     principal_first_name principal_middle_name principal_last_name  \
# 5                    NaN                   NaN                 NaN
# 113               MIGUEL                   NaN             SOLTERO
# 148               MANUEL               SANTANA              CHAMUL
# 161                 CARL                  JUAN             FROMMER
# 171              RICARDO             HERNANDEZ             AMEZCUA
# 237                 JOSE               ARNOLDO             ORANTES
# 263                GRANT                 DRAKE                MUIR
# 264                 FRED                   NaN          KHACHEKIAN
# 268                  BEN                   NaN              KISLER
# 275              MICHAEL                JOSEPH               BROWN
# 278                  NaN                   NaN                 NaN
# 315              VINCENT               ANTHONY               ROSSI
# 325               THOMAS                   NaN               REESE
# 331                DAVID                 ALLAN            NOWACZYK
# 334             EZEQUIEL                FRANCO            VILLEGAS
# 368                  NaN                   NaN                 NaN
# 429             BENJAMIN              JEREMIAH                 LIU
# 460              ELEAZAR                   NaN             BECERRA
# 483                AARON           CHRISTOPHER              SEMLER
# 486                  NaN                   NaN                 NaN
# 489                  NaN                   NaN                 NaN
#
#     license_expiration_date applicant_first_name applicant_last_name  \
# 5                       NaT                DAVID               LELIE
# 113              2018-09-30                  NaN                 NaN
# 148              2019-10-31              URIU  &          ASSOCIATES
# 161              2018-05-31                JENNY                DIAZ
# 171              2020-08-31              RICARDO             AMEZCUA
# 237              2019-02-28                  NaN                 NaN
# 263              2018-08-31              PHILLIP                HONS
# 264              2020-10-31                DIANA              OLIVAS
# 268              2017-05-31           TED MORENO                 NaN
# 275              2018-10-31                DAVID            SANDOVAL
# 278              2000-01-01                 ELSA                 NaN
# 315              2014-09-30                VANDA                 NaN
# 325              2020-01-31               THOMAS               REESE
# 331              2020-02-29                 DAVE            NOWACZYK
# 334              2019-05-31              MYCHAEL              MEHRIZ
# 368              2009-01-01                DAVID              EDFORD
# 429              2017-12-31                  NaN                 NaN
# 460              2017-10-31                  NaN                 NaN
# 483              2015-01-31                AARON              SEMLER
# 486              2009-01-01                  NaN                 NaN
# 489              2018-10-31               ROBERT                 NaN
#
#         applicant_business_name    applicant_address_1 applicant_address_2  \
# 5                           NaN   25152 SPRINGFIELD CT                #180
# 113                         NaN                    NaN                 NaN
# 148                         NaN     830 S GLENDALE AVE                 NaN
# 161                         NaN       1300 DOVE STREET                 100
# 171                         NaN                    NaN                 NaN
# 237                         NaN                    NaN                 NaN
# 263  MUIR-CHASE PLUMBING CO INC                    NaN                 NaN
# 264                         NaN                    NaN                 NaN
# 268                         NaN  9111 MORNING GLOW WAY                 NaN
# 275                         NaN       964 E BADILLO ST                 303
# 278                         NaN                    NaN                 NaN
# 315                         NaN        11280 CORBIN AV                 NaN
# 325                         NaN                    NaN                 NaN
# 331                         NaN                    NaN                 NaN
# 334                         NaN        7117 ALVERN ST.                E126
# 368                         NaN                    NaN                 NaN
# 429                         NaN                    NaN                 NaN
# 460                         NaN                    NaN                 NaN
# 483                         NaN           8342 JADE DR                 NaN
# 486                         NaN                    NaN                 NaN
# 489                         NaN                    NaN                 NaN
#
#       applicant_address_3           zone occupancy  \
# 5            VALENCIA, CA    (T)(Q)RD2-1       NaN
# 113                   NaN      R1-1-CUGU       NaN
# 148          GLENDALE, CA          RD2-1       NaN
# 161     NEWPORT BEACH, CA     (T)C2-2D-O       NaN
# 171                   NaN         R3-1XL       NaN
# 237                   NaN      RD1.5-1-O       NaN
# 263                   NaN         C2-2-O       NaN
# 264                   NaN  R1-1XL-O-CUGU       NaN
# 268        SUN VALLEY, CA         C2-1VL       NaN
# 275            COVINA, CA        [Q]R4-1       NaN
# 278                   NaN       (Q)RD6-1       NaN
# 315            NORTHRIDGE       [T]C4-2D       NaN
# 325                   NaN      [Q]R4-1-O       NaN
# 331                   NaN        [Q]R3-1       NaN
# 334       LOS ANGELES, CA          RD2-1       NaN
# 368                   NaN         A1-1XL       NaN
# 429                   NaN        RD1.5-1       NaN
# 460                   NaN           C2-2       NaN
# 483  RANCHO CUCAMONGA, CA           R3-1       NaN
# 486                   NaN           R1-1       NaN
# 489                   NaN            LAX       NaN
#
#     floor_area_la_building_code_definition census_tract  council_district  \
# 5                                     1985      1278.03                 6
# 113                                      0      1047.03                 7
# 148                                      0      1171.02                 7
# 161                                    NaN      2145.01                 4
# 171                                      0      1895.00                 4
# 237                                      0      2146.00                 5
# 263                                      0      2679.01                 5
# 264                                      0      2941.20                15
# 268                                      0      1945.00                 5
# 275                                      0      2213.04                10
# 278                                      0      1094.00                 7
# 315                                    NaN      1082.02                12
# 325                                      0      2164.02                 5
# 331                                    NaN      1351.14                 3
# 334                                   3645      2407.00                 9
# 368                                      0      1977.00                 1
# 429                                      0      2703.00                10
# 460                                      0      2071.03                 1
# 483                                      0      1395.03                 5
# 486                                      0      1200.10                 6
# 489                                      0      9800.28                11
#
#              latitude_longitude applicant_relationship  existing_code  \
# 5    (34.2003503, -118.4533963)        Agent for Owner            NaN
# 113    (34.2538783, -118.40469)                    NaN            NaN
# 148  (34.2498959, -118.4665838)              Architect            NaN
# 161    (34.072878, -118.357463)        Agent for Owner           21.0
# 171  (34.1068231, -118.3226816)             Contractor            NaN
# 237    (34.075354, -118.369252)                    NaN            NaN
# 263  (34.0605808, -118.4147074)   Agent for Contractor            NaN
# 264   (33.794012, -118.2435141)   Agent for Contractor            1.0
# 268  (34.0800261, -118.3617445)        Agent for Owner            NaN
# 275  (34.0451794, -118.3120002)          Net Applicant            NaN
# 278  (34.2673732, -118.4551213)   Agent for Contractor            NaN
# 315  (34.2782109, -118.5761633)        Agent for Owner            7.0
# 325  (34.0610864, -118.3826713)             Contractor            NaN
# 331  (34.1833658, -118.6138218)        Agent for Owner           35.0
# 334  (33.9509343, -118.2554957)        Agent for Owner            NaN
# 368  (34.0723102, -118.2479584)        Agent for Owner            NaN
# 429  (34.0372372, -118.3678237)             Contractor            NaN
# 460  (34.0632708, -118.2380873)                    NaN            NaN
# 483  (34.1679389, -118.5251225)          Net Applicant            NaN
# 486     (34.2177, -118.4624216)             Owner-Bldr            NaN
# 489  (33.9430891, -118.4076601)   Agent for Contractor            NaN
#
#      proposed_code                 full_address
# 5              1.0       7111 N MARISA RD 91405
# 113            NaN    12453 W BROMWICH ST 91331
# 148            NaN     9842 N LASSEN ROAD 91345
# 161            NaN     101 S THE GROVE DR 90036
# 171            NaN      1956 N CARMEN AVE 90068
# 237            NaN       135 N HARPER AVE 90048
# 263            NaN    1925 CENTURY PARK E 90067
# 264            NaN        1440 GAMBLE AVE 90744
# 268            NaN      465 N FAIRFAX AVE 90036
# 275            NaN   1511 S ST ANDREWS PL 90019
# 278            NaN    10846 N BONITA LANE 91345
# 315            NaN  20450 W SORRENTO LANE 91326
# 325            NaN       869 S WOOSTER ST 90035
# 331            NaN       6204 N SHOUP AVE 91367
# 334            2.0         1122 E 94TH ST 90002
# 368            NaN  1000 W VIN SCULLY AVE 90026
# 429            NaN   2307 S SPAULDING AVE 90016
# 460            NaN        833 N BROADWAY  90012
# 483            NaN   5339 N NEWCASTLE AVE 91316
# 486            NaN      8060 N WISNER AVE 91402
# 489            NaN          401 WORLD WAY 90045

# %%
# Check that there are no more missing coordinates before proceeding
assert data['latitude_longitude'].notnull().any(), "Missing coordinates must be geocoded."

# %% [markdown]
# #### 1.2.3 Split *latitude_longitude*
#
# Split coordinates into separate columns and convert to float values.

# %%
# Split latitude_longitude into separate columns and convert to float values: latitude, longitude
lat_long_series = data['latitude_longitude'].astype(str).str[1:-1].str.split(',', expand=True) \
                        .astype(float).rename(columns={0: "latitude", 1: "longitude"})

# Add to original data
data = pd.concat([data, lat_long_series], axis=1)

# %%
# Display
data[['latitude_longitude', 'latitude', 'longitude']].head(1)
# Out:
#        latitude_longitude  latitude  longitude
# 0  (34.05474, -118.42628)  34.05474 -118.42628

# %%
# Check for null values
assert data['latitude'].any(), 'Column "latitude" has missing values.'
assert data['longitude'].any(), 'Column "longitude" has missing values.'
