# %% [markdown]
# # permits-data / Clean Data
#
# ETL pipeline for construction permits data in Los Angeles, California, USA.
#
# For more information:
# https://data.lacity.org/A-Prosperous-City/Building-and-Safety-Permit-Information/yv23-pmwf

# %% [markdown]
# ## Setup

# %%
import os
import sys

# Set path for modules
sys.path[0] = '../'

from dotenv import load_dotenv, find_dotenv
import numpy as np
import pandas as pd

# SQL libraries
import psycopg2
print(psycopg2.__version__)

# Import custom eda and sql functions
from src.toolkits.eda import get_snapshot
from src.toolkits.sql import connect_db, get_table_names

# Import dependencies for geocoding
from geopy.geocoders import Nominatim
from geopy.geocoders import GoogleV3
from geopy.extra.rate_limiter import RateLimiter
# Out:
# 2.8.5 (dt dec pq3 ext lo64)

# %%
# Set notebook display options
pd.set_option('display.max_rows', 2000)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
# Get project root directory
root_dir = os.path.dirname(os.getcwd())

# Set environment variables
load_dotenv(find_dotenv());
POSTGRES_USER = os.getenv("POSTGRES_USER")
POSTGRES_PASSWORD = os.getenv("POSTGRES_PASSWORD")
POSTGRES_DB = os.getenv("POSTGRES_DB")
DB_PORT = os.getenv("DB_PORT")
DB_HOST = os.getenv("DB_HOST")
DATA_URL = os.getenv("DATA_URL")

# Google Maps environment variables
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
GOOGLE_AGENT = "permits-data"

# Environment variables specific to notebook
DATA_DIR = os.path.dirname(root_dir) + '/data'
DB_TABLE = "permits_raw"

# %% [markdown]
# ## 1. Clean Data

# %%
# Fetch data from postgres
def fetch_data(sql, con):
    
    # Fetch fresh data
    data = pd.read_sql_query(sql, con, coerce_float=False)

    # Replace None with np.nan
    data.fillna(np.nan, inplace=True)
    
    return data

# %%
# Connect to db
conn = connect_db()

# Extract partial dataset
sql = 'SELECT * FROM {} LIMIT 500;'.format(DB_TABLE)

# Columns to parse as dates
#date_columns = ['status_date', 'issue_date', 'license_expiration_date']

# Fetch data
data = fetch_data(sql, conn)
# Out:
# Connected as user "postgres" to database "permits" on http://localhost:5432.

# %% [markdown]
# ### 1.1 Missing Data

# %% [markdown]
# #### Overview of Unique Values in Qualitative Data
#
# Before making decisions about how to address missing values, it is important to be familiar with the content of each column. In some cases data can be left alone, imputed, recollected, or dropped from the dataset. Since the permits data has mostly qualitative data and unstructured text, most of it will be left alone.
#
# In the case of geographic data such as addresses and lat/long coordinates, it will be necessary to accurately geocode the missing values. Since this information is split across several columns they will be concatenated into one column.

# %%
# Get an overview of data types, # unique values, # missing values and sample value
# for each column
get_snapshot(data)
# Out:
#                                        DATA TYPE  # UNIQUE VALUES  \
# COLUMN
# assessor_book                             object              365
# assessor_page                             object               44
# assessor_parcel                           object               75
# tract                                     object              446
# block                                     object               52
# lot                                       object              155
# reference_no_old_permit_no                object              165
# pcis_permit_no                            object              500
# status                                    object                8
# status_date                               object              423
# permit_type                               object               15
# permit_sub_type                           object                5
# permit_category                           object                2
# project_number                            object                2
# initiating_office                         object                6
# issue_date                                object              437
# address_start                             object              476
# address_fraction_start                    object                2
# address_end                               object              476
# address_fraction_end                      object                2
# street_direction                          object                4
# street_name                               object              394
# street_suffix                             object               14
# suffix_direction                          object                2
# unit_range_start                          object               97
# unit_range_end                            object               10
# zip_code                                  object              105
# work_description                          object              187
# valuation                                 object               90
# floor_area_la_zoning_code_definition      object               20
# no_of_residential_dwelling_units          object                5
# no_of_stories                             object                4
# contractors_business_name                 object              378
# contractor_address                        object              379
# contractor_city                           object              149
# contractor_state                          object               13
# license_type                              object               16
# license_no                                object              369
# principal_first_name                      object              231
# principal_middle_name                     object              182
# principal_last_name                       object              352
# license_expiration_date                   object               94
# applicant_first_name                      object              269
# applicant_last_name                       object              292
# applicant_business_name                   object               38
# applicant_address_1                       object              239
# applicant_address_2                       object               65
# applicant_address_3                       object              120
# zone                                      object              166
# occupancy                                 object                2
# floor_area_la_building_code_definition    object               29
# census_tract                              object              341
# council_district                          object               15
# latitude_longitude                        object              478
# applicant_relationship                    object               11
# existing_code                             object               14
# proposed_code                             object               12
#
#                                         # MISSING VALUES  \
# COLUMN
# assessor_book                                          0
# assessor_page                                          0
# assessor_parcel                                        0
# tract                                                  3
# block                                                384
# lot                                                    4
# reference_no_old_permit_no                           304
# pcis_permit_no                                         0
# status                                                 0
# status_date                                            0
# permit_type                                            0
# permit_sub_type                                        0
# permit_category                                        0
# project_number                                       495
# initiating_office                                      0
# issue_date                                             0
# address_start                                          0
# address_fraction_start                               495
# address_end                                            0
# address_fraction_end                                 483
# street_direction                                       8
# street_name                                            0
# street_suffix                                         11
# suffix_direction                                     496
# unit_range_start                                     396
# unit_range_end                                       490
# zip_code                                               0
# work_description                                     304
# valuation                                            342
# floor_area_la_zoning_code_definition                 465
# no_of_residential_dwelling_units                     485
# no_of_stories                                        467
# contractors_business_name                              0
# contractor_address                                    52
# contractor_city                                       57
# contractor_state                                      57
# license_type                                           0
# license_no                                             0
# principal_first_name                                  45
# principal_middle_name                                192
# principal_last_name                                   49
# license_expiration_date                               38
# applicant_first_name                                 115
# applicant_last_name                                  156
# applicant_business_name                              443
# applicant_address_1                                  225
# applicant_address_2                                  413
# applicant_address_3                                  227
# zone                                                   0
# occupancy                                            494
# floor_area_la_building_code_definition                92
# census_tract                                           0
# council_district                                       0
# latitude_longitude                                    19
# applicant_relationship                                13
# existing_code                                        379
# proposed_code                                        455
#
#                                                                      SAMPLE VALUE
# COLUMN
# assessor_book                                                                2688
# assessor_page                                                                 029
# assessor_parcel                                                               036
# tract                                                                     TR 3631
# block                                                                           U
# lot                                                                           121
# reference_no_old_permit_no                                                   15LA
# pcis_permit_no                                                  15041-90000-35045
# status                                                             Permit Finaled
# status_date                                                            10/29/2015
# permit_type                                                            Electrical
# permit_sub_type                                            1 or 2 Family Dwelling
# permit_category                                                        Plan Check
# project_number                                                                  4
# initiating_office                                                        VAN NUYS
# issue_date                                                             09/16/2014
# address_start                                                                1290
# address_fraction_start                                                        1/2
# address_end                                                                  8124
# address_fraction_end                                                          1/4
# street_direction                                                                E
# street_name                                                             VIA DOLCE
# street_suffix                                                                  ST
# suffix_direction                                                             EAST
# unit_range_start                                                         50TH FLR
# unit_range_end                                                             BLDG 8
# zip_code                                                                    90019
# work_description                        New NFPA13D system for TWO STORY SFD/GAR.
# valuation                                                                28200.00
# floor_area_la_zoning_code_definition                                            0
# no_of_residential_dwelling_units                                                0
# no_of_stories                                                                   1
# contractors_business_name                                    AFFORDABLE ADDITIONS
# contractor_address                                       6957 HAZELTINE AVENUE #4
# contractor_city                                                        WILMINGTON
# contractor_state                                                               CA
# license_type                                                                  C20
# license_no                                                                      0
# principal_first_name                                                      NETANEL
# principal_middle_name                                                     JOAQUIN
# principal_last_name                                                      MARTINEZ
# license_expiration_date                                                12/31/2018
# applicant_first_name                                                         MARK
# applicant_last_name                                                       BATIOFF
# applicant_business_name                                             OWNER-BUILDER
# applicant_address_1                                                 16137 VALERIO
# applicant_address_2                                                       SUITE A
# applicant_address_3                                          RANCHO CUCAMONGA, CA
# zone                                                                         R1-1
# occupancy                                                        Misc. Occ. Group
# floor_area_la_building_code_definition                                          0
# census_tract                                                              2393.20
# council_district                                                               10
# latitude_longitude                                         (34.16883, -118.53867)
# applicant_relationship                                              Net Applicant
# existing_code                                                                   7
# proposed_code                                                                  60

# %% [markdown]
# At the moment the only missing data of interest are *zip_code* and *latitude_longitude* coordinates, since these are necesary for mapping.

# %% [markdown]
# ### 1.2 Processing Missing Data
#
# ***Overview:***
# * 1.2.1 - Combine address columns into one columns: *full_address*<br>
#     - Correct *suffix_direction*
#     - Convert *zip_code* to string
#     - Concatenate to form *full_address*
# * 1.2.2 - Geocode missing *latitude_longitude* with *full_address*<br>
# * 1.2.3 - Split *latitude_longitude* into separate columns and convert to float values: *latitude*, *longitude*<br>
# <br>
# * Geocode missing *zip_code* with complete *latitude_longitude*<br>
# * Geocode any missing *full_address* with *latitude_longitude*<br>

# %% [markdown]
# #### 1.2.1 Concatenate *full_address*
#
# 1) Correct values *suffix_direction*.<br>
# 2) Convert *zip_code* to string.<br>
# 3) Concatenate to form a complete street address string.

# %%
def create_column_full_address(data):

    # Truncate suffix_direction to first letter (N, S, E, W)
    data['suffix_direction'] = data['suffix_direction'].str[0].fillna('')

    # Convert zip_code to string
    data['zip_code'] = data['zip_code'].fillna('').astype(str)

    # Combine address columns to concatenate
    address_columns = ["address_start", "street_direction", "street_name", "street_suffix", "suffix_direction",
                      "zip_code"]

    # Concatenate address values
    data['full_address'] = data[address_columns].fillna('').astype(str).apply(' '.join, axis=1).str.replace('  ', ' ')

    # Replace empty strings with NaN values
    data[address_columns] = data[address_columns].replace('', np.nan)
    
    return data

# %%
data = create_column_full_address(data)

# %%
# Display
data[address_columns + ['full_address']].head()
# Out:
#   address_start street_direction street_name street_suffix suffix_direction  \
# 0          1823                S      THAYER           AVE              NaN
# 1          2122                W        54TH            ST              NaN
# 2           415                S  BURLINGTON           AVE              NaN
# 3           315                S      OCEANO            DR              NaN
# 4         13640                W      PIERCE            ST              NaN
#
#   zip_code                full_address
# 0    90025     1823 S THAYER AVE 90025
# 1    90062        2122 W 54TH ST 90062
# 2    90057  415 S BURLINGTON AVE 90057
# 3    90049       315 S OCEANO DR 90049
# 4    91331     13640 W PIERCE ST 91331

# %% [markdown]
# #### 1.2.2 Geocode missing *latitude_longitude*

# %%
# Extract rows missing in latitude_longitude
data_missing = data[data['latitude_longitude'].isnull()==1]

# Size
data_missing.shape
# Out:
# (19, 60)

# %%
# Display
data_missing[['full_address', 'latitude_longitude']].head()
# Out:
#                   full_address latitude_longitude
# 5       7111 N MARISA RD 91405                NaN
# 112  12453 W BROMWICH ST 91331                NaN
# 146   9842 N LASSEN ROAD 91345                NaN
# 160   101 S THE GROVE DR 90036                NaN
# 170    1956 N CARMEN AVE 90068                NaN

# %%
# Create helper function to geocode missing latitude_longitude values
def geocode(address, key, agent, timeout=None):
    
    """
    Uses GoogleMaps API to batch geocode address strings to lat/long coordinates. RateLimiter is to 
    avoid timeout errors. If an address cannot be geocoded it is left as NaN. Use of GoogleMaps 
    API incurs a charge at $0.005 per request.
    
    
    """
    
    if address:
        # Initializes GoogleMaps geocoder
        geolocator = GoogleV3(api_key=key, user_agent=agent, timeout=timeout)

        # Adds Rate Limiter to space out requests
        geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

        # Geocode address input and format for dataframe
        location = geolocator.geocode(address)
        #print(address, location.latitude)
        
        latitude, longitude = location.latitude, location.longitude
        
        return latitude, longitude
    else:
        return np.nan

# %%
# Calculate cost
cost = len(data_missing) * 0.005
print("Cost for geocoding {} addresses is ${:.2f}.".format(len(data_missing), cost))

# Geocode missing coordinates using full addresses
if len(data_missing) > 0:
    data_missing['latitude_longitude'] = data_missing['full_address'].apply(geocode, args=(GOOGLE_API_KEY, 
                                                                                       "permits-data"))

# Update dataframe
data.update(data_missing)
# Out:
# Cost for geocoding 19 addresses is $0.10.
# /Users/gregory/anaconda3/envs/permits-data-env/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Display
data_missing[['full_address', 'latitude_longitude']].head()
# Out:
#                   full_address          latitude_longitude
# 5       7111 N MARISA RD 91405  (34.2003503, -118.4533963)
# 112  12453 W BROMWICH ST 91331    (34.2538783, -118.40469)
# 146   9842 N LASSEN ROAD 91345  (34.2498959, -118.4665838)
# 160   101 S THE GROVE DR 90036    (34.072878, -118.357463)
# 170    1956 N CARMEN AVE 90068  (34.1068231, -118.3226816)

# %% [markdown]
# #### 1.2.3 Split *latitude_longitude*
#
# Split coordinates into separate columns and convert to float values.

# %%
def split_column_lat_long(data):
    
    # Check that there are no more missing coordinates before proceeding
    assert data['latitude_longitude'].notnull().any(), "Missing coordinates must be geocoded."

    # Split latitude_longitude into separate columns and convert to float values: latitude, longitude
    if ['latitude', 'longitude'] not in data.columns.tolist():
        lat_long_series = data['latitude_longitude'].astype(str).str[1:-1].str.split(',', expand=True) \
                            .astype(float).rename(columns={0: "latitude", 1: "longitude"})

        # Add to original data
        return pd.concat([data, lat_long_series], axis=1)

# %%
data = split_column_lat_long(data)

# %%
# Display
data[['latitude_longitude', 'latitude', 'longitude']].head(1)
# Out:
#        latitude_longitude  latitude  longitude
# 0  (34.05474, -118.42628)  34.05474 -118.42628

# %%
def save_csv(data, path, reorder=False):

    # Check unique columns
    assert data.columns.tolist() == data.columns.unique().tolist(), "Extra columns detected."
    
    # Check for null values
    assert data['latitude'].any(), 'Column "latitude" has missing values.'
    assert data['longitude'].any(), 'Column "longitude" has missing values.'

    # Check for erroneous coordinates. All coordinates should fall within Los Angeles county.
    assert (data['latitude'] > 33.2).all() and (data['latitude'] < 34.9).all(), "Incorrect latitude detected"
    assert (data['longitude'] > -118.9).all() and (data['longitude'] < -118).all(), "Incorrect longitude detected"

    if reorder:
        # Fetch names in postgres table and use to reorder columns dataframe
        columns_reordered = get_table_names(DB_TABLE, conn).tolist()
        data = data[columns_reordered]
        print("Columns are correctly reordered.")
    
    # Write to csv
    data.to_csv(path, index=False)
    
    return

# %%
# Path to csv
sql_path = root_dir + '/data/interim/permits_geocoded.csv'

# Reorder rows

# Save to interim folder
save_csv(data, sql_path)

# %%
data.shape
# Out:
# (500, 62)

# %% [markdown]
# ## 2. Update PostgreSQL Database

# %%
# Connect to db
conn = connect_db()

# Extract partial dataset
sql = 'SELECT * FROM {} LIMIT 500;'.format(DB_TABLE)

# Columns to parse as dates
#date_columns = ['status_date', 'issue_date', 'license_expiration_date']

# Fetch data
data = pd.read_csv(root_dir + '/data/interim/permits_geocoded.csv')
# Out:
# Connected as user "postgres" to database "permits" on http://localhost:5432.

# %%
data.head()
# Out:
#    assessor_book  assessor_page assessor_parcel                tract block  \
# 0           4317              3             ***           TR 30210-C   NaN
# 1           5005             10             017  CHESTERFIELD SQUARE   NaN
# 2           5154             23             022        SUN-SET TRACT     D
# 3           4404             30             010             TR 12086   NaN
# 4           2646             19             011              TR 7158   NaN
#
#     lot reference_no_old_permit_no     pcis_permit_no          status  \
# 0  LT 1                        NaN  15044-90000-08405  Permit Finaled
# 1   465                  16SL57806  16016-70000-02464  Permit Finaled
# 2    13                  14VN81535  14016-20000-13092          Issued
# 3     2                        NaN  16044-30000-09658  Permit Finaled
# 4    11                        NaN  17042-90000-31792  Permit Finaled
#
#   status_date        permit_type         permit_sub_type permit_category  \
# 0  09/10/2015               HVAC  1 or 2 Family Dwelling   No Plan Check
# 1  08/01/2017  Bldg-Alter/Repair  1 or 2 Family Dwelling   No Plan Check
# 2  08/13/2014  Bldg-Alter/Repair               Apartment      Plan Check
# 3  08/29/2016               HVAC  1 or 2 Family Dwelling   No Plan Check
# 4  12/28/2017           Plumbing  1 or 2 Family Dwelling   No Plan Check
#
#    project_number  event_code initiating_office  issue_date  address_start  \
# 0             NaN         NaN          INTERNET  08/18/2015           1823
# 1             NaN         NaN          SOUTH LA  02/04/2016           2122
# 2             NaN         NaN          VAN NUYS  08/13/2014            415
# 3             NaN         NaN           WEST LA  08/22/2016            315
# 4             NaN         NaN          INTERNET  12/26/2017          13640
#
#   address_fraction_start  address_end address_fraction_end street_direction  \
# 0                    1/2         1823                  1/2                S
# 1                    NaN         2122                  NaN                W
# 2                    NaN          415                  NaN                S
# 3                    NaN          315                  NaN                S
# 4                    NaN        13640                  NaN                W
#
#   street_name street_suffix suffix_direction unit_range_start unit_range_end  \
# 0      THAYER           AVE              NaN              NaN            NaN
# 1        54TH            ST              NaN              NaN            NaN
# 2  BURLINGTON           AVE              NaN             1-30           1-30
# 3      OCEANO            DR              NaN              NaN            NaN
# 4      PIERCE            ST              NaN              NaN            NaN
#
#    zip_code                                   work_description  valuation  \
# 0     90025                                                NaN        NaN
# 1     90062  General rehabilitation for single family dwell...    40000.0
# 2     90057  PHOTOVOLTAIC SOLAR PANELS ON ROOF OF (E) APT BLDG    37000.0
# 3     90049                                                NaN        NaN
# 4     91331                                                NaN        NaN
#
#    floor_area_la_zoning_code_definition  no_of_residential_dwelling_units  \
# 0                                   NaN                               NaN
# 1                                   NaN                               NaN
# 2                                   NaN                               NaN
# 3                                   NaN                               NaN
# 4                                   NaN                               NaN
#
#    no_of_accessory_dwelling_units  no_of_stories  \
# 0                             NaN            NaN
# 1                             NaN            NaN
# 2                             NaN            NaN
# 3                             NaN            NaN
# 4                             NaN            NaN
#
#                        contractors_business_name      contractor_address  \
# 0  CONDITIONED AIRE MECHANICAL & ENGINEERING INC  18650 PARTHENIA STREET
# 1                                  OWNER-BUILDER                     NaN
# 2                    PERMACITY CONSTRUCTION CORP  5570 W WASHINGTON BLVD
# 3                  E/C HEATING AND AIR CONDITION  26888 CUATRO MILPAS ST
# 4                             TITANIUM POWER INC  1545 S LA CIENEGA BLVD
#
#   contractor_city contractor_state license_type  license_no  \
# 0      NORTHRIDGE               CA          C20      532440
# 1             NaN              NaN          NaN           0
# 2     LOS ANGELES               CA            B      827864
# 3        VALENCIA               CA          C20      651051
# 4     LOS ANGELES               CA            B      989217
#
#   principal_first_name principal_middle_name principal_last_name  \
# 0                BRETT                 MOORE              HOFFER
# 1               JAVIER                   NaN          TALAMANTES
# 2             JONATHAN                  SAUL                PORT
# 3                  EDY               RUDOLFO              CORDON
# 4               DENNIS                 HARUO            MIYAHIRA
#
#   license_expiration_date applicant_first_name applicant_last_name  \
# 0              06/30/2016                BRETT              HOFFER
# 1                     NaN               JAVIER          TALAMANTES
# 2              11/30/2015                LINDA              MARTON
# 3              07/31/2018                  NaN                 NaN
# 4              12/31/2017                 YONI            GHERMEZI
#
#   applicant_business_name     applicant_address_1 applicant_address_2  \
# 0                     NaN      18650 PARTHENIA ST                 NaN
# 1           OWNER-BUILDER                     NaN                 NaN
# 2                     NaN       710 WILSHIRE BLVD                 NaN
# 3                     NaN                     NaN                 NaN
# 4                     NaN  1545 S LA CIENEGA BLVD                 NaN
#
#   applicant_address_3    zone occupancy  \
# 0      NORTHRIDGE, CA  R3-1-O       NaN
# 1                 NaN  C2-1VL       NaN
# 2    SANTA MONICA, CA    R4-1       NaN
# 3                 NaN    RS-1       NaN
# 4     LOS ANGELES, CA  R1-1-O       NaN
#
#    floor_area_la_building_code_definition  census_tract  council_district  \
# 0                                     0.0       2671.00                 5
# 1                                     NaN       2325.00                 8
# 2                                     NaN       2089.04                 1
# 3                                     0.0       2640.00                11
# 4                                     0.0       1044.03                 7
#
#        latitude_longitude applicant_relationship  existing_code  \
# 0  (34.05474, -118.42628)          Net Applicant            NaN
# 1  (33.99307, -118.31668)             Owner-Bldr            1.0
# 2  (34.06012, -118.26997)        Agent for Owner            5.0
# 3   (34.05707, -118.4732)             Contractor            NaN
# 4  (34.25487, -118.43002)          Net Applicant            NaN
#
#    proposed_code                full_address  latitude  longitude
# 0            NaN     1823 S THAYER AVE 90025  34.05474 -118.42628
# 1            NaN        2122 W 54TH ST 90062  33.99307 -118.31668
# 2            NaN  415 S BURLINGTON AVE 90057  34.06012 -118.26997
# 3            NaN       315 S OCEANO DR 90049  34.05707 -118.47320
# 4            NaN     13640 W PIERCE ST 91331  34.25487 -118.43002

# %% [markdown]
# ### 2.1 Add New Columns
#
# A list of current columns is retrieved and compared to the new columns. Current columns will be updated with new columns if they are not already present. One important issue is that the order of columns in PostgreSQL is different than the order of columns in the Pandas dataframe. The solution is to ensure that they both have the same order so that values do not end up in the wrong column.

# %%
def add_columns(db_table, con, run=False):

    # Get names of current columns in PostgreSQL table
    current_names = get_table_names(db_table, con)

    # Get names of updated table not in current table
    updated_names = data.columns.tolist()
    new_names = list(set(updated_names) - set(current_names))
    
    # Check names list is not empty
    if not new_names:
        print("Table is up to date.")
        return

    # Format strings for query
    alter_table_sql = "ALTER TABLE {db_table}\n"
    add_column_sql = "\tADD COLUMN {column} TEXT,\n"

    # Create a list and append ADD column statements
    sql_query = [alter_table_sql.format(db_table=db_table)]
    for name in new_names:
        sql_query.append(add_column_sql.format(column=name))

    # Join into one string
    sql_query = ''.join(sql_query)[:-2] + ";"
    
    if run:
        ### ADD TRY/EXCEPT TO RUN QUERY AGAINST DB
        try:
            print("Connecting...")
            cur = con.cursor()
            print("Executing query...")
            cur.execute(sql_query)
            print("Committing changes...")
            con.commit()
            cur.close()
            print("Database updated successfully:\nAdd columns {}".format(', '.join(new_names)))
        except Exception as e:
            conn.rollback()
            print('Error:\n', e)
    
    return sql_query

# %%
print(alter_table_query)
# Out:
# ALTER TABLE permits_raw
# 	ADD COLUMN latitude TEXT,
# 	ADD COLUMN longitude TEXT,
# 	ADD COLUMN full_address TEXT;

# %%
alter_table_query = add_columns(DB_TABLE, conn, run=True)
# Out:
# Connecting...
# Executing query...
# Committing changes...
# Database updated successfully:
# Add columns latitude, longitude, full_address

# %%
# Path to csv
sql_path = root_dir + '/data/interim/permits_geocoded.csv'

# Resave with reordered columns
save_csv(data, sql_path, reorder=True)
# Out:
# Columns are correctly reordered.

# %% [markdown]
# ### 2.2 Update Table

# %%
data_path = '/var/local/data/interim/permits_geocoded.csv' # Path within container for COPY command
sql_path = root_dir + '/postgres/sql/update_table_values.sql'
print(data_path)
print(sql_path)
# Out:
# /var/local/data/interim/permits_geocoded.csv
# /Users/gregory/Documents/00 Data Projects/project-portfolio/permits-data/postgres/sql/update_table_values.sql

# %%
### ORIGINAL
# Builds a query to update from a csv file
def update_table_values(db_table, con, data_path, sql_path, run=False):

    # CREATE TABLE and COPY
    tmp_table = "tmp_" + db_table
    
    column_names = get_table_names(db_table, con)
    column_names = column_names.tolist()
    names = ',\n\t'.join(['{}'.format(name) + " TEXT" for name in column_names])

    create_tmp_table_sql = 'CREATE TABLE public.{tmp_table} (\n\t{names}\n);\n\n'.format(tmp_table=tmp_table, names=names)
    copy_from_table_sql = "COPY public.{tmp_table} FROM \'{data_path}\' (FORMAT csv, HEADER TRUE);\n\nUPDATE {db_table}\n".format(tmp_table=tmp_table, 
                                                                                                   data_path=data_path, db_table=db_table)

    # SET statements
    updates_sql = ["SET "]

    for name in column_names:
        original_name = '{}'.format(name)
        set_sql = "{name} = {tmp_name},\n\t".format(name=original_name, 
                                                   tmp_name=tmp_table + '.' + name)
        updates_sql.append(set_sql)

    updates_sql = ''.join(updates_sql)

    updates_sql = updates_sql[:-3] + "\n"

    # FROM and WHERE clause
    tail_sql = "FROM public.{tmp_table}\nWHERE {db_table}.pcis_permit_no = {tmp_table}.pcis_permit_no;\n" \
        .format(tmp_table=tmp_table, db_table=db_table)

    sql_query = create_tmp_table_sql + copy_from_table_sql + updates_sql + tail_sql
    
    if run:
        ### ADD TRY/EXCEPT TO RUN QUERY AGAINST DB
        try:
            cur = con.cursor()
            print("Executing...")
            cur.execute(sql_query)
            con.commit()
            cur.close()
            print('Table "{}" is updated.'.format(db_table))
        except Exception as e:
            con.rollback()
            print('Error:\n', e)
    
    return sql_query

# %%
update_table_values_query = update_table_values(DB_TABLE, con=conn, data_path=data_path, sql_path=sql_path, run=True)
# Out:
# Executing...
# Connection closed.

# %%
print(update_table_values_query)
# Out:
# CREATE TABLE public.tmp_permits_raw (
# 	assessor_book TEXT,
# 	assessor_page TEXT,
# 	assessor_parcel TEXT,
# 	tract TEXT,
# 	block TEXT,
# 	lot TEXT,
# 	reference_no_old_permit_no TEXT,
# 	pcis_permit_no TEXT,
# 	status TEXT,
# 	status_date TEXT,
# 	permit_type TEXT,
# 	permit_sub_type TEXT,
# 	permit_category TEXT,
# 	project_number TEXT,
# 	event_code TEXT,
# 	initiating_office TEXT,
# 	issue_date TEXT,
# 	address_start TEXT,
# 	address_fraction_start TEXT,
# 	address_end TEXT,
# 	address_fraction_end TEXT,
# 	street_direction TEXT,
# 	street_name TEXT,
# 	street_suffix TEXT,
# 	suffix_direction TEXT,
# 	unit_range_start TEXT,
# 	unit_range_end TEXT,
# 	zip_code TEXT,
# 	work_description TEXT,
# 	valuation TEXT,
# 	floor_area_la_zoning_code_definition TEXT,
# 	no_of_residential_dwelling_units TEXT,
# 	no_of_accessory_dwelling_units TEXT,
# 	no_of_stories TEXT,
# 	contractors_business_name TEXT,
# 	contractor_address TEXT,
# 	contractor_city TEXT,
# 	contractor_state TEXT,
# 	license_type TEXT,
# 	license_no TEXT,
# 	principal_first_name TEXT,
# 	principal_middle_name TEXT,
# 	principal_last_name TEXT,
# 	license_expiration_date TEXT,
# 	applicant_first_name TEXT,
# 	applicant_last_name TEXT,
# 	applicant_business_name TEXT,
# 	applicant_address_1 TEXT,
# 	applicant_address_2 TEXT,
# 	applicant_address_3 TEXT,
# 	zone TEXT,
# 	occupancy TEXT,
# 	floor_area_la_building_code_definition TEXT,
# 	census_tract TEXT,
# 	council_district TEXT,
# 	latitude_longitude TEXT,
# 	applicant_relationship TEXT,
# 	existing_code TEXT,
# 	proposed_code TEXT,
# 	latitude TEXT,
# 	longitude TEXT,
# 	full_address TEXT
# );
#
# COPY public.tmp_permits_raw FROM '/var/local/data/interim/permits_geocoded.csv' (FORMAT csv, HEADER TRUE);
#
# UPDATE permits_raw
# SET assessor_book = tmp_permits_raw.assessor_book,
# 	assessor_page = tmp_permits_raw.assessor_page,
# 	assessor_parcel = tmp_permits_raw.assessor_parcel,
# 	tract = tmp_permits_raw.tract,
# 	block = tmp_permits_raw.block,
# 	lot = tmp_permits_raw.lot,
# 	reference_no_old_permit_no = tmp_permits_raw.reference_no_old_permit_no,
# 	pcis_permit_no = tmp_permits_raw.pcis_permit_no,
# 	status = tmp_permits_raw.status,
# 	status_date = tmp_permits_raw.status_date,
# 	permit_type = tmp_permits_raw.permit_type,
# 	permit_sub_type = tmp_permits_raw.permit_sub_type,
# 	permit_category = tmp_permits_raw.permit_category,
# 	project_number = tmp_permits_raw.project_number,
# 	event_code = tmp_permits_raw.event_code,
# 	initiating_office = tmp_permits_raw.initiating_office,
# 	issue_date = tmp_permits_raw.issue_date,
# 	address_start = tmp_permits_raw.address_start,
# 	address_fraction_start = tmp_permits_raw.address_fraction_start,
# 	address_end = tmp_permits_raw.address_end,
# 	address_fraction_end = tmp_permits_raw.address_fraction_end,
# 	street_direction = tmp_permits_raw.street_direction,
# 	street_name = tmp_permits_raw.street_name,
# 	street_suffix = tmp_permits_raw.street_suffix,
# 	suffix_direction = tmp_permits_raw.suffix_direction,
# 	unit_range_start = tmp_permits_raw.unit_range_start,
# 	unit_range_end = tmp_permits_raw.unit_range_end,
# 	zip_code = tmp_permits_raw.zip_code,
# 	work_description = tmp_permits_raw.work_description,
# 	valuation = tmp_permits_raw.valuation,
# 	floor_area_la_zoning_code_definition = tmp_permits_raw.floor_area_la_zoning_code_definition,
# 	no_of_residential_dwelling_units = tmp_permits_raw.no_of_residential_dwelling_units,
# 	no_of_accessory_dwelling_units = tmp_permits_raw.no_of_accessory_dwelling_units,
# 	no_of_stories = tmp_permits_raw.no_of_stories,
# 	contractors_business_name = tmp_permits_raw.contractors_business_name,
# 	contractor_address = tmp_permits_raw.contractor_address,
# 	contractor_city = tmp_permits_raw.contractor_city,
# 	contractor_state = tmp_permits_raw.contractor_state,
# 	license_type = tmp_permits_raw.license_type,
# 	license_no = tmp_permits_raw.license_no,
# 	principal_first_name = tmp_permits_raw.principal_first_name,
# 	principal_middle_name = tmp_permits_raw.principal_middle_name,
# 	principal_last_name = tmp_permits_raw.principal_last_name,
# 	license_expiration_date = tmp_permits_raw.license_expiration_date,
# 	applicant_first_name = tmp_permits_raw.applicant_first_name,
# 	applicant_last_name = tmp_permits_raw.applicant_last_name,
# 	applicant_business_name = tmp_permits_raw.applicant_business_name,
# 	applicant_address_1 = tmp_permits_raw.applicant_address_1,
# 	applicant_address_2 = tmp_permits_raw.applicant_address_2,
# 	applicant_address_3 = tmp_permits_raw.applicant_address_3,
# 	zone = tmp_permits_raw.zone,
# 	occupancy = tmp_permits_raw.occupancy,
# 	floor_area_la_building_code_definition = tmp_permits_raw.floor_area_la_building_code_definition,
# 	census_tract = tmp_permits_raw.census_tract,
# 	council_district = tmp_permits_raw.council_district,
# 	latitude_longitude = tmp_permits_raw.latitude_longitude,
# 	applicant_relationship = tmp_permits_raw.applicant_relationship,
# 	existing_code = tmp_permits_raw.existing_code,
# 	proposed_code = tmp_permits_raw.proposed_code,
# 	latitude = tmp_permits_raw.latitude,
# 	longitude = tmp_permits_raw.longitude,
# 	full_address = tmp_permits_raw.full_address
# FROM public.tmp_permits_raw
# WHERE permits_raw.pcis_permit_no = tmp_permits_raw.pcis_permit_no;

# %% [markdown]
# #### Check Update Success

# %%
# Connect to db
conn = connect_db()

# Extract partial dataset
sql = 'SELECT * FROM {} LIMIT 500;'.format(DB_TABLE)

# Columns to parse as dates
#date_columns = ['status_date', 'issue_date', 'license_expiration_date']

# Fetch data
data = fetch_data(sql, conn)

# Display
data.head(10)
# Out:
# Connected as user "postgres" to database "permits" on http://localhost:5432.
#   assessor_book assessor_page assessor_parcel                  tract block  \
# 0          2027             4             011               TR 26618   NaN
# 1          4317             3             ***             TR 30210-C   NaN
# 2          5005            10             017    CHESTERFIELD SQUARE   NaN
# 3          5154            23             022          SUN-SET TRACT     D
# 4          4404            30             010               TR 12086   NaN
# 5          2646            19             011                TR 7158   NaN
# 6          2219            27             052               TR 73820   NaN
# 7          2748            27             001               TR 22446   NaN
# 8          4234             9             009               TR 19428   NaN
# 9          5154            13             011  NORTH KNOB HILL TRACT   NaN
#
#     lot reference_no_old_permit_no     pcis_permit_no          status  \
# 0    11                        NaN  17042-90000-21398          Issued
# 1  LT 1                        NaN  15044-90000-08405  Permit Finaled
# 2   465                  16SL57806  16016-70000-02464  Permit Finaled
# 3    13                  14VN81535  14016-20000-13092          Issued
# 4     2                        NaN  16044-30000-09658  Permit Finaled
# 5    11                        NaN  17042-90000-31792  Permit Finaled
# 6    52                  18VN77133  17010-20000-02747     CofO Issued
# 7   298                       14LA  14041-10000-02537  Permit Finaled
# 8    19                  16WL75914  16016-30000-26238  Permit Finaled
# 9    27                        NaN  18042-20000-12284  Permit Finaled
#
#   status_date        permit_type         permit_sub_type permit_category  \
# 0  08/30/2017           Plumbing  1 or 2 Family Dwelling   No Plan Check
# 1  09/10/2015               HVAC  1 or 2 Family Dwelling   No Plan Check
# 2  08/01/2017  Bldg-Alter/Repair  1 or 2 Family Dwelling   No Plan Check
# 3  08/13/2014  Bldg-Alter/Repair               Apartment      Plan Check
# 4  08/29/2016               HVAC  1 or 2 Family Dwelling   No Plan Check
# 5  12/28/2017           Plumbing  1 or 2 Family Dwelling   No Plan Check
# 6  04/05/2019           Bldg-New  1 or 2 Family Dwelling      Plan Check
# 7  10/16/2014         Electrical  1 or 2 Family Dwelling      Plan Check
# 8  06/27/2018  Bldg-Alter/Repair               Apartment   No Plan Check
# 9  05/30/2018           Plumbing               Apartment   No Plan Check
#
#   project_number  event_code initiating_office  issue_date address_start  \
# 0            NaN         NaN          INTERNET  08/30/2017         23311
# 1            NaN         NaN          INTERNET  08/18/2015          1823
# 2            NaN         NaN          SOUTH LA  02/04/2016          2122
# 3            NaN         NaN          VAN NUYS  08/13/2014           415
# 4            NaN         NaN           WEST LA  08/22/2016           315
# 5            NaN         NaN          INTERNET  12/26/2017         13640
# 6            NaN         NaN          VAN NUYS  09/21/2018          7111
# 7            NaN         NaN             METRO  04/09/2014          9672
# 8            NaN         NaN           WEST LA  11/01/2016          3755
# 9            NaN         NaN          VAN NUYS  05/21/2018           229
#
#   address_fraction_start address_end address_fraction_end street_direction  \
# 0                    NaN       23311                  NaN                W
# 1                    1/2        1823                  1/2                S
# 2                    NaN        2122                  NaN                W
# 3                    NaN         415                  NaN                S
# 4                    NaN         315                  NaN                S
# 5                    NaN       13640                  NaN                W
# 6                    NaN        7111                  NaN                N
# 7                    NaN        9672                  NaN                N
# 8                    NaN        3755                  NaN                S
# 9                    NaN         233                  NaN                S
#
#   street_name street_suffix suffix_direction unit_range_start unit_range_end  \
# 0      WINDOM            ST              NaN              NaN            NaN
# 1      THAYER           AVE              NaN              NaN            NaN
# 2        54TH            ST              NaN              NaN            NaN
# 3  BURLINGTON           AVE              NaN             1-30           1-30
# 4      OCEANO            DR              NaN              NaN            NaN
# 5      PIERCE            ST              NaN              NaN            NaN
# 6      MARISA            RD              NaN              NaN            NaN
# 7     LARAMIE           AVE              NaN              PV1            NaN
# 8      BUTLER           AVE              NaN            1 & 7            NaN
# 9    CRANDALL            ST              NaN              NaN            NaN
#
#   zip_code                                   work_description valuation  \
# 0    91304                                                NaN       NaN
# 1    90025                                                NaN       NaN
# 2    90062  General rehabilitation for single family dwell...   40000.0
# 3    90057  PHOTOVOLTAIC SOLAR PANELS ON ROOF OF (E) APT BLDG   37000.0
# 4    90049                                                NaN       NaN
# 5    91331                                                NaN       NaN
# 6    91405                   NEW SFD/GARAGE - PLAN 1A, LOT-52  196660.0
# 7    91311  5.8 KW DC ROOF MOUNT PV, (24) MODULES, (1) TRA...       NaN
# 8    90066  KITCHEN AND BATHROOM REMODEL FOR RESIDENTIAL B...   12000.0
# 9    90057                                                NaN       NaN
#
#   floor_area_la_zoning_code_definition no_of_residential_dwelling_units  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
# 5                                  NaN                              NaN
# 6                               1560.0                              1.0
# 7                                  NaN                              NaN
# 8                                  NaN                              NaN
# 9                                  NaN                              NaN
#
#    no_of_accessory_dwelling_units no_of_stories  \
# 0                             NaN           NaN
# 1                             NaN           NaN
# 2                             NaN           NaN
# 3                             NaN           NaN
# 4                             NaN           NaN
# 5                             NaN           NaN
# 6                             NaN           2.0
# 7                             NaN           NaN
# 8                             NaN           NaN
# 9                             NaN           NaN
#
#                        contractors_business_name          contractor_address  \
# 0                                  OWNER-BUILDER                         NaN
# 1  CONDITIONED AIRE MECHANICAL & ENGINEERING INC      18650 PARTHENIA STREET
# 2                                  OWNER-BUILDER                         NaN
# 3                    PERMACITY CONSTRUCTION CORP      5570 W WASHINGTON BLVD
# 4                  E/C HEATING AND AIR CONDITION      26888 CUATRO MILPAS ST
# 5                             TITANIUM POWER INC      1545 S LA CIENEGA BLVD
# 6                                  OWNER-BUILDER                         NaN
# 7                         SMART ENERGY SOLAR INC        1641 COMMERCE STREET
# 8                                     AMARO MARK  3230 MERRILL DRIVE UNIT 77
# 9         L G S COMPLIANCE ALLIANCE RETROFITTING        675 S GLENWOOD PLACE
#
#   contractor_city contractor_state license_type license_no  \
# 0             NaN              NaN          NaN          0
# 1      NORTHRIDGE               CA          C20     532440
# 2             NaN              NaN          NaN          0
# 3     LOS ANGELES               CA            B     827864
# 4        VALENCIA               CA          C20     651051
# 5     LOS ANGELES               CA            B     989217
# 6             NaN              NaN          NaN          0
# 7          CORONA               CA          C46     990049
# 8        TORRANCE               CA            B     954226
# 9         BURBANK               CA          C36     900919
#
#   principal_first_name principal_middle_name principal_last_name  \
# 0                  NaN                   NaN                 NaN
# 1                BRETT                 MOORE              HOFFER
# 2               JAVIER                   NaN          TALAMANTES
# 3             JONATHAN                  SAUL                PORT
# 4                  EDY               RUDOLFO              CORDON
# 5               DENNIS                 HARUO            MIYAHIRA
# 6                  NaN                   NaN                 NaN
# 7             LEOBARDO               JOAQUIN            BAUTISTA
# 8                 MARK                   NaN               AMARO
# 9                 GLEN                   ROY         CHRISTENSEN
#
#   license_expiration_date applicant_first_name applicant_last_name  \
# 0                     NaN              KRISTEN              IMHOFF
# 1              06/30/2016                BRETT              HOFFER
# 2                     NaN               JAVIER          TALAMANTES
# 3              11/30/2015                LINDA              MARTON
# 4              07/31/2018                  NaN                 NaN
# 5              12/31/2017                 YONI            GHERMEZI
# 6                     NaN                DAVID               LELIE
# 7              01/31/2016                  NaN                 NaN
# 8              11/30/2016                 MARK               AMARO
# 9              07/31/2019                RAMON                 NaN
#
#   applicant_business_name     applicant_address_1 applicant_address_2  \
# 0                     NaN              5048 CAMPO                 NaN
# 1                     NaN      18650 PARTHENIA ST                 NaN
# 2           OWNER-BUILDER                     NaN                 NaN
# 3                     NaN       710 WILSHIRE BLVD                 NaN
# 4                     NaN                     NaN                 NaN
# 5                     NaN  1545 S LA CIENEGA BLVD                 NaN
# 6                     NaN    25152 SPRINGFIELD CT                #180
# 7                     NaN                     NaN                 NaN
# 8                     NaN                     NaN                 NaN
# 9                     NaN                     NaN                 NaN
#
#   applicant_address_3         zone occupancy  \
# 0  WOODLAND HILLS, CA       RE11-1       NaN
# 1      NORTHRIDGE, CA       R3-1-O       NaN
# 2                 NaN       C2-1VL       NaN
# 3    SANTA MONICA, CA         R4-1       NaN
# 4                 NaN         RS-1       NaN
# 5     LOS ANGELES, CA       R1-1-O       NaN
# 6        VALENCIA, CA  (T)(Q)RD2-1       NaN
# 7                 NaN         RS-1       NaN
# 8                 NaN         R3-1       NaN
# 9                 NaN         R3-1       NaN
#
#   floor_area_la_building_code_definition census_tract council_district  \
# 0                                    0.0      1344.22               12
# 1                                    0.0       2671.0                5
# 2                                    NaN       2325.0                8
# 3                                    NaN      2089.04                1
# 4                                    0.0       2640.0               11
# 5                                    0.0      1044.03                7
# 6                                 1985.0      1278.03                6
# 7                                    0.0      1133.03               12
# 8                                    NaN      2719.01               11
# 9                                    0.0      2085.02               13
#
#            latitude_longitude applicant_relationship existing_code  \
# 0      (34.20709, -118.63795)             Owner-Bldr           NaN
# 1      (34.05474, -118.42628)          Net Applicant           NaN
# 2      (33.99307, -118.31668)             Owner-Bldr           1.0
# 3      (34.06012, -118.26997)        Agent for Owner           5.0
# 4       (34.05707, -118.4732)             Contractor           NaN
# 5      (34.25487, -118.43002)          Net Applicant           NaN
# 6  (34.2003503, -118.4533963)        Agent for Owner           NaN
# 7      (34.24591, -118.57345)             Contractor           NaN
# 8      (34.01023, -118.42294)             Contractor           5.0
# 9      (34.06634, -118.27401)   Agent for Contractor           NaN
#
#   proposed_code            latitude     longitude                full_address
# 0           NaN            34.20709    -118.63795     23311 W WINDOM ST 91304
# 1           NaN            34.05474    -118.42628     1823 S THAYER AVE 90025
# 2           NaN            33.99307    -118.31668        2122 W 54TH ST 90062
# 3           NaN            34.06012    -118.26997  415 S BURLINGTON AVE 90057
# 4           NaN            34.05707     -118.4732       315 S OCEANO DR 90049
# 5           NaN  34.254870000000004    -118.43002     13640 W PIERCE ST 91331
# 6           1.0          34.2003503  -118.4533963      7111 N MARISA RD 91405
# 7           NaN  34.245909999999995    -118.57345    9672 N LARAMIE AVE 91311
# 8           NaN            34.01023    -118.42294     3755 S BUTLER AVE 90066
# 9           NaN  34.066340000000004    -118.27401     229 S CRANDALL ST 90057

# %%
data.shape
# Out:
# (500, 62)
